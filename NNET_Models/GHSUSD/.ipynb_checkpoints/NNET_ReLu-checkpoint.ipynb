# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../datasets/Interbank FX Rates Historical (full).csv')
df.head()
# Out:
#           Date  USDGHS  GBPGHS
# 0  31 Dec 2020  7.8787  5.7631
# 1  30 Dec 2020  7.8087  5.7371
# 2  29 Dec 2020  7.7383  5.7351
# 3  24 Dec 2020  7.7779  5.7351
# 4  23 Dec 2020  7.7344  5.7241

# %%
df['USDGHS'] = pd.to_numeric(df['USDGHS'], errors='coerce')
df['GBPGHS'] = pd.to_numeric(df['GBPGHS'], errors='coerce')
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
# Resample the DataFrame to a daily frequency and forward-fill missing values
df = df.resample('D').ffill()
df = df.fillna(method='bfill')
df.describe()
# Out:
#             USDGHS       GBPGHS
# count  4748.000000  4748.000000
# mean      4.320325     3.040635
# std       1.846412     1.547481
# min       0.000000     0.000000
# 25%       2.454700     1.522400
# 50%       4.878600     3.011850
# 75%       5.922800     4.404125
# max       7.878700     5.763100

# %%
USDGHS = df['USDGHS']

# %% [markdown]
# It is not necessary to check for autocorrelation in time series before using LSTM. However, it is important to check for autocorrelation in time series data before using any time series model. Autocorrelation is a measure of the correlation between the values of a time series at different points in time. If there is autocorrelation in the data, it means that the values of the time series at one point in time are correlated with the values at other points in time. This can lead to biased estimates of the model parameters and can affect the accuracy of the model predictions

# %%
def Model_data_setup(data, lookback, delay, min_index, max_index):
    """
    data:     Shape (n_samples, n_features). First column is the time series, other columns are the features.
              If there is only one column, it is assumed to be the time series data.
    lookback: Number of time steps in the Model >= 1
    delay:    The number of time steps to predict >= 1.
    min_index,max_index: The starting and ending indices of the time series portion to construct the data.
                         Allows constructing validation and test sets from the series in proper shape
    Returns: A tuple (x, y) of numpy arrays where x is in shape (n_samples, n_timesteps, n_features) and 
             y is in shape (n_samples, delay). y is an array of target arrays each of size delay. To forecast 
             a single value n timesteps ahead, set delay = n and take the last element of the forecast array.
    """
    if data.ndim == 1:
        data = np.expand_dims(data, axis=1)
    n_samples = max_index - lookback - delay + 1
    x_shape = (n_samples, lookback, data.shape[1])
    x = np.zeros(x_shape)
    y_shape = (n_samples, delay)
    y = np.zeros(y_shape)

    for i in range(n_samples):
        start_index = i + min_index
        end_index = start_index + lookback
        x[i,:,:] = data[start_index:end_index,:]
        y[i,:] = data[end_index + delay - 1, 0]

    return x, y

# %%
xdata, ydata = Model_data_setup(USDGHS.values, lookback=5, delay=1, min_index=0, max_index=len(USDGHS)-1)

# %% [markdown]
# ### Splitting the dataset into the training and testing sets
#
# We are splitting the dataset of normalized stock Rates into 80$\%$ and 20$\%$ for training and testing respectively. 20 $\%$ of training set will be assigned for validation at later stage.

# %%
#Specifying the sizes of training and testing datasets.
train_size = int(len(xdata)*0.6) # 2416#
valid_size = int(len(xdata)*0.2) #605#
test_size = len(xdata) - train_size-valid_size #355#

#Splitting the dataset into trainig, validation and testing.
xtrain, xvalid, xtest = xdata[0:train_size,:], xdata[train_size:train_size+valid_size,:], xdata[train_size+valid_size:len(xdata),:]
ytrain, yvalid, ytest = ydata[0:train_size,:], ydata[train_size:train_size+valid_size,:], ydata[train_size+valid_size:len(ydata),:]

print('The shape of the training sample is: ', xtrain.shape)
print('The shape of the validation sample is: ', xvalid.shape)
print('The shape of the testing sample is: ', xtest.shape)
print('The shape of the training target is: ', ytrain.shape)
print('The shape of the validation target is: ', yvalid.shape)
print('The shape of the testing target is: ', ytest.shape)
# Out:
# The shape of the training sample is:  (2845, 5, 1)
# The shape of the validation sample is:  (948, 5, 1)
# The shape of the testing sample is:  (949, 5, 1)
# The shape of the training target is:  (2845, 1)
# The shape of the validation target is:  (948, 1)
# The shape of the testing target is:  (949, 1)

# %%
xtrain = np.reshape(xtrain, (xtrain.shape[0], xtrain.shape[1], -1))
xvalid = np.reshape(xvalid, (xvalid.shape[0], xvalid.shape[1], -1))
xtest = np.reshape(xtest, (xtest.shape[0], xtest.shape[1], -1))
xtrain.shape,xvalid.shape,xtest.shape
# Out:
# ((2845, 5, 1), (948, 5, 1), (949, 5, 1))

# %% [markdown]
# ## Neural Networks Models

# %%
from keras.models import Sequential
from keras.models import Model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, SimpleRNN, LSTM,GRU,Conv1D, ConvLSTM2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Reshape
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
n_features = USDGHS.shape
lr = 0.0016#Learning rate
units = 16 #Number hidden units
batch_size=64
lookback = 5
delay = 1
min_index = 0
max_index = USDGHS.shape[0] - 1

# Define the number of features in the input data
n_features = 1  # We only have one feature, which is the USDGHS exchange rate

# Convert the data into the required format for the model
xdata, ydata = Model_data_setup(USDGHS.values.reshape(-1, 1), lookback, delay, min_index, max_index)

# %%
# Define RNN model
RNN = Sequential()
RNN.add(SimpleRNN(units, activation='relu', input_shape=(lookback, n_features), return_sequences=False, recurrent_dropout=0.3))
RNN.add(Dense(5))
RNN.add(Reshape((5, 1)))

RNN.compile(optimizer='Adam', loss='mse', metrics=['mae'])
RNN.summary()
np.random.seed(123)
history_1=RNN.fit(xtrain,ytrain, validation_data=(xvalid,yvalid),
                   epochs=50,
                   verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 16)                288
#
#  dense (Dense)               (None, 5)                 85
#
#  reshape (Reshape)           (None, 5, 1)              0
#
# =================================================================
# Total params: 373
# Trainable params: 373
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 89/89 [==============================] - 11s 25ms/step - loss: 12.1682 - mae: 3.0679 - val_loss: 19.0351 - val_mae: 4.1209
# Epoch 2/50
# 89/89 [==============================] - 1s 11ms/step - loss: 3.4969 - mae: 1.4458 - val_loss: 1.1603 - val_mae: 0.9756
# Epoch 3/50
# 89/89 [==============================] - 1s 11ms/step - loss: 1.1004 - mae: 0.7799 - val_loss: 0.6743 - val_mae: 0.7082
# Epoch 4/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.6040 - mae: 0.5699 - val_loss: 0.5537 - val_mae: 0.6699
# Epoch 5/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.4151 - mae: 0.4651 - val_loss: 0.5073 - val_mae: 0.6627
# Epoch 6/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.3040 - mae: 0.3930 - val_loss: 0.5380 - val_mae: 0.6934
# Epoch 7/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.2401 - mae: 0.3451 - val_loss: 0.4105 - val_mae: 0.5953
# Epoch 8/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.1918 - mae: 0.3040 - val_loss: 0.4313 - val_mae: 0.6220
# Epoch 9/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.1487 - mae: 0.2646 - val_loss: 0.3326 - val_mae: 0.5429
# Epoch 10/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.1210 - mae: 0.2331 - val_loss: 0.2774 - val_mae: 0.4933
# Epoch 11/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.1019 - mae: 0.2089 - val_loss: 0.2812 - val_mae: 0.5042
# Epoch 12/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0907 - mae: 0.1907 - val_loss: 0.2007 - val_mae: 0.4228
# Epoch 13/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0775 - mae: 0.1730 - val_loss: 0.2115 - val_mae: 0.4398
# Epoch 14/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0677 - mae: 0.1558 - val_loss: 0.1686 - val_mae: 0.3920
# Epoch 15/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0618 - mae: 0.1437 - val_loss: 0.1495 - val_mae: 0.3695
# Epoch 16/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0587 - mae: 0.1361 - val_loss: 0.1233 - val_mae: 0.3353
# Epoch 17/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0534 - mae: 0.1251 - val_loss: 0.1031 - val_mae: 0.3043
# Epoch 18/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0515 - mae: 0.1192 - val_loss: 0.0771 - val_mae: 0.2593
# Epoch 19/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0479 - mae: 0.1125 - val_loss: 0.0656 - val_mae: 0.2390
# Epoch 20/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0452 - mae: 0.1038 - val_loss: 0.0834 - val_mae: 0.2747
# Epoch 21/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0429 - mae: 0.0979 - val_loss: 0.0621 - val_mae: 0.2339
# Epoch 22/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0400 - mae: 0.0927 - val_loss: 0.0505 - val_mae: 0.2084
# Epoch 23/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0382 - mae: 0.0877 - val_loss: 0.0504 - val_mae: 0.2079
# Epoch 24/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0376 - mae: 0.0845 - val_loss: 0.0460 - val_mae: 0.1990
# Epoch 25/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0367 - mae: 0.0809 - val_loss: 0.0449 - val_mae: 0.1956
# Epoch 26/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0371 - mae: 0.0782 - val_loss: 0.0382 - val_mae: 0.1804
# Epoch 27/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0355 - mae: 0.0742 - val_loss: 0.0321 - val_mae: 0.1622
# Epoch 28/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0318 - mae: 0.0697 - val_loss: 0.0308 - val_mae: 0.1590
# Epoch 29/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0337 - mae: 0.0692 - val_loss: 0.0271 - val_mae: 0.1456
# Epoch 30/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0321 - mae: 0.0656 - val_loss: 0.0204 - val_mae: 0.1229
# Epoch 31/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0316 - mae: 0.0623 - val_loss: 0.0248 - val_mae: 0.1341
# Epoch 32/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0325 - mae: 0.0615 - val_loss: 0.0180 - val_mae: 0.1117
# Epoch 33/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0295 - mae: 0.0594 - val_loss: 0.0188 - val_mae: 0.1137
# Epoch 34/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0281 - mae: 0.0572 - val_loss: 0.0196 - val_mae: 0.1178
# Epoch 35/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0298 - mae: 0.0570 - val_loss: 0.0135 - val_mae: 0.0945
# Epoch 36/50
# 89/89 [==============================] - 1s 14ms/step - loss: 0.0295 - mae: 0.0552 - val_loss: 0.0117 - val_mae: 0.0899
# Epoch 37/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0324 - mae: 0.0533 - val_loss: 0.0172 - val_mae: 0.1099
# Epoch 38/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0282 - mae: 0.0517 - val_loss: 0.0158 - val_mae: 0.1033
# Epoch 39/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0283 - mae: 0.0511 - val_loss: 0.0099 - val_mae: 0.0811
# Epoch 40/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0296 - mae: 0.0514 - val_loss: 0.0142 - val_mae: 0.0982
# Epoch 41/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0278 - mae: 0.0498 - val_loss: 0.0150 - val_mae: 0.1046
# Epoch 42/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0279 - mae: 0.0501 - val_loss: 0.0130 - val_mae: 0.0972
# Epoch 43/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0270 - mae: 0.0477 - val_loss: 0.0137 - val_mae: 0.0985
# Epoch 44/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0272 - mae: 0.0479 - val_loss: 0.0179 - val_mae: 0.1122
# Epoch 45/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0294 - mae: 0.0479 - val_loss: 0.0075 - val_mae: 0.0690
# Epoch 46/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0267 - mae: 0.0456 - val_loss: 0.0154 - val_mae: 0.1024
# Epoch 47/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0264 - mae: 0.0458 - val_loss: 0.0143 - val_mae: 0.1006
# Epoch 48/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0281 - mae: 0.0455 - val_loss: 0.0092 - val_mae: 0.0762
# Epoch 49/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0273 - mae: 0.0465 - val_loss: 0.0081 - val_mae: 0.0720
# Epoch 50/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0287 - mae: 0.0452 - val_loss: 0.0094 - val_mae: 0.0786

# %%
RNN_df = pd.DataFrame(history_1.history)
print('')
plt.figure(figsize=(9,5))
plt.plot(RNN_df['loss'], label ='Training loss (MSE)', color = 'blue')
plt.plot(RNN_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
plt.xlabel('Mini-batch', fontsize=13)
plt.ylabel('Loss', fontsize=13)
plt.legend(fontsize=13)
# plt.savefig('../images/RNN_error1.png', format='png', dpi=1000)
plt.show()

# %%
LSTM_Model = tf.keras.models.Sequential([
    Input(shape=(lookback, n_features)),
    LSTM(32, activation='relu', return_sequences=True),
    LSTM(32, activation='relu'),
    Dense(5)
    # Reshape((5, 1))
])

LSTM_Model.compile(loss='mse', optimizer='Adam' , metrics=["mae"])
LSTM_Model.summary()

np.random.seed(123)
history_2=LSTM_Model.fit(xtrain,ytrain, validation_data=(xvalid,yvalid), epochs=50, verbose=1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 5, 32)             4352
#
#  lstm_2 (LSTM)               (None, 32)                8320
#
#  dense_2 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 12,837
# Trainable params: 12,837
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 89/89 [==============================] - 14s 36ms/step - loss: 4.1416 - mae: 1.6764 - val_loss: 0.2215 - val_mae: 0.3735
# Epoch 2/50
# 89/89 [==============================] - 2s 22ms/step - loss: 0.0897 - mae: 0.1740 - val_loss: 0.0151 - val_mae: 0.0960
# Epoch 3/50
# 89/89 [==============================] - 2s 22ms/step - loss: 0.0462 - mae: 0.0863 - val_loss: 0.0135 - val_mae: 0.0919
# Epoch 4/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0419 - mae: 0.0723 - val_loss: 0.0223 - val_mae: 0.1297
# Epoch 5/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0395 - mae: 0.0707 - val_loss: 0.0072 - val_mae: 0.0649
# Epoch 6/50
# 89/89 [==============================] - 2s 19ms/step - loss: 0.0367 - mae: 0.0634 - val_loss: 0.0058 - val_mae: 0.0569
# Epoch 7/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0347 - mae: 0.0573 - val_loss: 0.0061 - val_mae: 0.0589
# Epoch 8/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0348 - mae: 0.0605 - val_loss: 0.0048 - val_mae: 0.0511
# Epoch 9/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0341 - mae: 0.0574 - val_loss: 0.0062 - val_mae: 0.0595
# Epoch 10/50
# 89/89 [==============================] - 2s 22ms/step - loss: 0.0346 - mae: 0.0608 - val_loss: 0.0085 - val_mae: 0.0747
# Epoch 11/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0344 - mae: 0.0604 - val_loss: 0.0162 - val_mae: 0.1123
# Epoch 12/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0343 - mae: 0.0610 - val_loss: 0.0061 - val_mae: 0.0602
# Epoch 13/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0334 - mae: 0.0545 - val_loss: 0.0041 - val_mae: 0.0471
# Epoch 14/50
# 89/89 [==============================] - 2s 22ms/step - loss: 0.0333 - mae: 0.0571 - val_loss: 0.0085 - val_mae: 0.0748
# Epoch 15/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0334 - mae: 0.0578 - val_loss: 0.0368 - val_mae: 0.1800
# Epoch 16/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0328 - mae: 0.0576 - val_loss: 0.0077 - val_mae: 0.0707
# Epoch 17/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0333 - mae: 0.0597 - val_loss: 0.0036 - val_mae: 0.0438
# Epoch 18/50
# 89/89 [==============================] - 2s 22ms/step - loss: 0.0327 - mae: 0.0593 - val_loss: 0.0052 - val_mae: 0.0552
# Epoch 19/50
# 89/89 [==============================] - 2s 22ms/step - loss: 0.0318 - mae: 0.0582 - val_loss: 0.0065 - val_mae: 0.0641
# Epoch 20/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0304 - mae: 0.0522 - val_loss: 0.0049 - val_mae: 0.0538
# Epoch 21/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0312 - mae: 0.0601 - val_loss: 0.0737 - val_mae: 0.2622
# Epoch 22/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0316 - mae: 0.0625 - val_loss: 0.0046 - val_mae: 0.0515
# Epoch 23/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0311 - mae: 0.0620 - val_loss: 0.0042 - val_mae: 0.0488
# Epoch 24/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0292 - mae: 0.0527 - val_loss: 0.0047 - val_mae: 0.0530
# Epoch 25/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0305 - mae: 0.0642 - val_loss: 0.0051 - val_mae: 0.0561
# Epoch 26/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0292 - mae: 0.0551 - val_loss: 0.0079 - val_mae: 0.0748
# Epoch 27/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0294 - mae: 0.0586 - val_loss: 0.0053 - val_mae: 0.0596
# Epoch 28/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0279 - mae: 0.0499 - val_loss: 0.0061 - val_mae: 0.0647
# Epoch 29/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0277 - mae: 0.0509 - val_loss: 0.0027 - val_mae: 0.0379
# Epoch 30/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0273 - mae: 0.0479 - val_loss: 0.0025 - val_mae: 0.0364
# Epoch 31/50
# 89/89 [==============================] - 2s 22ms/step - loss: 0.0271 - mae: 0.0501 - val_loss: 0.0031 - val_mae: 0.0417
# Epoch 32/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0267 - mae: 0.0479 - val_loss: 0.0180 - val_mae: 0.1251
# Epoch 33/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0279 - mae: 0.0575 - val_loss: 0.0027 - val_mae: 0.0407
# Epoch 34/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0256 - mae: 0.0437 - val_loss: 0.0020 - val_mae: 0.0324
# Epoch 35/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0258 - mae: 0.0451 - val_loss: 0.0015 - val_mae: 0.0266
# Epoch 36/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0259 - mae: 0.0492 - val_loss: 0.0023 - val_mae: 0.0364
# Epoch 37/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0262 - mae: 0.0511 - val_loss: 0.0063 - val_mae: 0.0708
# Epoch 38/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0258 - mae: 0.0480 - val_loss: 0.0029 - val_mae: 0.0447
# Epoch 39/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0254 - mae: 0.0426 - val_loss: 0.0029 - val_mae: 0.0445
# Epoch 40/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0251 - mae: 0.0435 - val_loss: 0.0027 - val_mae: 0.0422
# Epoch 41/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0255 - mae: 0.0458 - val_loss: 0.0016 - val_mae: 0.0293
# Epoch 42/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0246 - mae: 0.0407 - val_loss: 0.0040 - val_mae: 0.0534
# Epoch 43/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0258 - mae: 0.0487 - val_loss: 0.0031 - val_mae: 0.0461
# Epoch 44/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0256 - mae: 0.0482 - val_loss: 0.0014 - val_mae: 0.0256
# Epoch 45/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0254 - mae: 0.0464 - val_loss: 0.0056 - val_mae: 0.0673
# Epoch 46/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0246 - mae: 0.0392 - val_loss: 0.0323 - val_mae: 0.1761
# Epoch 47/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0249 - mae: 0.0447 - val_loss: 0.0016 - val_mae: 0.0288
# Epoch 48/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0255 - mae: 0.0484 - val_loss: 0.0039 - val_mae: 0.0533
# Epoch 49/50
# 89/89 [==============================] - 2s 21ms/step - loss: 0.0255 - mae: 0.0540 - val_loss: 0.0026 - val_mae: 0.0418
# Epoch 50/50
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0244 - mae: 0.0435 - val_loss: 0.0020 - val_mae: 0.0348

# %%
LSTM_df = pd.DataFrame(history_2.history)
print('')
plt.figure(figsize=(9,5))
plt.plot(LSTM_df['loss'], label ='Training loss (MSE)', color = 'blue')
plt.plot(LSTM_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
plt.xlabel('Mini-batch', fontsize=13)
plt.ylabel('Loss', fontsize=13)
plt.legend(fontsize=13)
# plt.savefig('../images/LSTM_error1.png', format='png', dpi=1000)
plt.show()

# %%
# Define GRU model
GRU_Model = tf.keras.models.Sequential([
    Input(shape=(lookback, n_features)),
    GRU(128, return_sequences=True),
    Dense(5),
    Dense(1)
])

GRU_Model.compile(optimizer = 'Adam', loss='mse', metrics=["mae"])
GRU_Model.summary()
np.random.seed(123)
history_3=GRU_Model.fit(xtrain,ytrain, validation_data=(xvalid,yvalid), epochs=50, verbose=1)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 5, 128)            50304
#
#  dense_3 (Dense)             (None, 5, 5)              645
#
#  dense_4 (Dense)             (None, 5, 1)              6
#
# =================================================================
# Total params: 50,955
# Trainable params: 50,955
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 89/89 [==============================] - 17s 54ms/step - loss: 1.6307 - mae: 0.8215 - val_loss: 0.6891 - val_mae: 0.5159
# Epoch 2/50
# 89/89 [==============================] - 2s 28ms/step - loss: 0.1388 - mae: 0.2093 - val_loss: 0.0806 - val_mae: 0.1804
# Epoch 3/50
# 89/89 [==============================] - 2s 28ms/step - loss: 0.0602 - mae: 0.0984 - val_loss: 0.0246 - val_mae: 0.1252
# Epoch 4/50
# 89/89 [==============================] - 2s 28ms/step - loss: 0.0541 - mae: 0.0812 - val_loss: 0.0178 - val_mae: 0.0996
# Epoch 5/50
# 89/89 [==============================] - 2s 28ms/step - loss: 0.0524 - mae: 0.0759 - val_loss: 0.0175 - val_mae: 0.1158
# Epoch 6/50
# 89/89 [==============================] - 3s 28ms/step - loss: 0.0508 - mae: 0.0705 - val_loss: 0.0087 - val_mae: 0.0664
# Epoch 7/50
# 89/89 [==============================] - 3s 29ms/step - loss: 0.0492 - mae: 0.0630 - val_loss: 0.0071 - val_mae: 0.0589
# Epoch 8/50
# 89/89 [==============================] - 2s 28ms/step - loss: 0.0487 - mae: 0.0626 - val_loss: 0.0106 - val_mae: 0.0882
# Epoch 9/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0478 - mae: 0.0588 - val_loss: 0.0051 - val_mae: 0.0506
# Epoch 10/50
# 89/89 [==============================] - 3s 31ms/step - loss: 0.0470 - mae: 0.0568 - val_loss: 0.0050 - val_mae: 0.0504
# Epoch 11/50
# 89/89 [==============================] - 3s 30ms/step - loss: 0.0471 - mae: 0.0627 - val_loss: 0.0041 - val_mae: 0.0456
# Epoch 12/50
# 89/89 [==============================] - 3s 29ms/step - loss: 0.0474 - mae: 0.0662 - val_loss: 0.0044 - val_mae: 0.0472
# Epoch 13/50
# 89/89 [==============================] - 3s 30ms/step - loss: 0.0466 - mae: 0.0623 - val_loss: 0.0041 - val_mae: 0.0456
# Epoch 14/50
# 89/89 [==============================] - 3s 31ms/step - loss: 0.0464 - mae: 0.0644 - val_loss: 0.0043 - val_mae: 0.0469
# Epoch 15/50
# 89/89 [==============================] - 3s 30ms/step - loss: 0.0453 - mae: 0.0563 - val_loss: 0.0099 - val_mae: 0.0837
# Epoch 16/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0458 - mae: 0.0639 - val_loss: 0.0067 - val_mae: 0.0656
# Epoch 17/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0452 - mae: 0.0635 - val_loss: 0.0054 - val_mae: 0.0560
# Epoch 18/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0452 - mae: 0.0627 - val_loss: 0.0055 - val_mae: 0.0577
# Epoch 19/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0449 - mae: 0.0630 - val_loss: 0.0136 - val_mae: 0.1034
# Epoch 20/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0452 - mae: 0.0693 - val_loss: 0.0042 - val_mae: 0.0468
# Epoch 21/50
# 89/89 [==============================] - 2s 28ms/step - loss: 0.0449 - mae: 0.0658 - val_loss: 0.0173 - val_mae: 0.1151
# Epoch 22/50
# 89/89 [==============================] - 3s 29ms/step - loss: 0.0455 - mae: 0.0696 - val_loss: 0.0057 - val_mae: 0.0579
# Epoch 23/50
# 89/89 [==============================] - 3s 28ms/step - loss: 0.0435 - mae: 0.0577 - val_loss: 0.0042 - val_mae: 0.0469
# Epoch 24/50
# 89/89 [==============================] - 3s 28ms/step - loss: 0.0453 - mae: 0.0719 - val_loss: 0.0067 - val_mae: 0.0659
# Epoch 25/50
# 89/89 [==============================] - 3s 30ms/step - loss: 0.0434 - mae: 0.0624 - val_loss: 0.0046 - val_mae: 0.0500
# Epoch 26/50
# 89/89 [==============================] - 3s 28ms/step - loss: 0.0434 - mae: 0.0611 - val_loss: 0.0104 - val_mae: 0.0851
# Epoch 27/50
# 89/89 [==============================] - 2s 28ms/step - loss: 0.0435 - mae: 0.0635 - val_loss: 0.0084 - val_mae: 0.0764
# Epoch 28/50
# 89/89 [==============================] - 3s 28ms/step - loss: 0.0432 - mae: 0.0641 - val_loss: 0.0083 - val_mae: 0.0738
# Epoch 29/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0426 - mae: 0.0606 - val_loss: 0.0045 - val_mae: 0.0493
# Epoch 30/50
# 89/89 [==============================] - 3s 29ms/step - loss: 0.0432 - mae: 0.0632 - val_loss: 0.0042 - val_mae: 0.0465
# Epoch 31/50
# 89/89 [==============================] - 2s 28ms/step - loss: 0.0432 - mae: 0.0703 - val_loss: 0.0064 - val_mae: 0.0632
# Epoch 32/50
# 89/89 [==============================] - 3s 28ms/step - loss: 0.0440 - mae: 0.0730 - val_loss: 0.0127 - val_mae: 0.0989
# Epoch 33/50
# 89/89 [==============================] - 2s 28ms/step - loss: 0.0425 - mae: 0.0632 - val_loss: 0.0043 - val_mae: 0.0478
# Epoch 34/50
# 89/89 [==============================] - 2s 28ms/step - loss: 0.0421 - mae: 0.0623 - val_loss: 0.0054 - val_mae: 0.0553
# Epoch 35/50
# 89/89 [==============================] - 3s 29ms/step - loss: 0.0426 - mae: 0.0679 - val_loss: 0.0073 - val_mae: 0.0682
# Epoch 36/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0418 - mae: 0.0600 - val_loss: 0.0044 - val_mae: 0.0478
# Epoch 37/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0423 - mae: 0.0662 - val_loss: 0.0039 - val_mae: 0.0452
# Epoch 38/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0415 - mae: 0.0606 - val_loss: 0.0066 - val_mae: 0.0636
# Epoch 39/50
# 89/89 [==============================] - 2s 26ms/step - loss: 0.0417 - mae: 0.0658 - val_loss: 0.0134 - val_mae: 0.1016
# Epoch 40/50
# 89/89 [==============================] - 2s 26ms/step - loss: 0.0425 - mae: 0.0687 - val_loss: 0.0059 - val_mae: 0.0603
# Epoch 41/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0413 - mae: 0.0654 - val_loss: 0.0162 - val_mae: 0.1123
# Epoch 42/50
# 89/89 [==============================] - 2s 26ms/step - loss: 0.0414 - mae: 0.0685 - val_loss: 0.0040 - val_mae: 0.0455
# Epoch 43/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0407 - mae: 0.0618 - val_loss: 0.0053 - val_mae: 0.0564
# Epoch 44/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0430 - mae: 0.0752 - val_loss: 0.0039 - val_mae: 0.0449
# Epoch 45/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0403 - mae: 0.0633 - val_loss: 0.0042 - val_mae: 0.0467
# Epoch 46/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0396 - mae: 0.0592 - val_loss: 0.0045 - val_mae: 0.0492
# Epoch 47/50
# 89/89 [==============================] - 2s 27ms/step - loss: 0.0411 - mae: 0.0671 - val_loss: 0.0055 - val_mae: 0.0577
# Epoch 48/50
# 89/89 [==============================] - 2s 28ms/step - loss: 0.0396 - mae: 0.0625 - val_loss: 0.0040 - val_mae: 0.0463
# Epoch 49/50
# 89/89 [==============================] - 2s 26ms/step - loss: 0.0393 - mae: 0.0590 - val_loss: 0.0042 - val_mae: 0.0469
# Epoch 50/50
# 89/89 [==============================] - 2s 26ms/step - loss: 0.0397 - mae: 0.0640 - val_loss: 0.0040 - val_mae: 0.0451

# %%
GRU_df =pd.DataFrame(history_3.history)
plt.figure(figsize=(9,5))
plt.plot(GRU_df['loss'], label ='Training loss (MSE)', color = 'blue')
plt.plot(GRU_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
plt.xlabel('Mini-batch', fontsize=13)
plt.ylabel('Loss', fontsize=13)
plt.legend(fontsize=13)
# plt.savefig('images/GRU_error1.png', format='png', dpi=1000)
plt.show()

# %%
# Define MLP model
MLP_Model = tf.keras.models.Sequential([
    Input(shape=(lookback, n_features)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(5)
    # Reshape((5,1))
])

MLP_Model.compile(optimizer = 'Adam', loss='mse', metrics=["mae"])
MLP_Model.summary()

np.random.seed(123)
history_4 = MLP_Model.fit(xtrain, ytrain,
                          epochs=50,
                          validation_data=(xvalid, yvalid))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 5)                 0
#
#  dense_5 (Dense)             (None, 64)                384
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 2,629
# Trainable params: 2,629
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 89/89 [==============================] - 6s 15ms/step - loss: 4.3266 - mae: 1.4567 - val_loss: 0.0273 - val_mae: 0.1283
# Epoch 2/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0352 - mae: 0.0826 - val_loss: 0.0064 - val_mae: 0.0685
# Epoch 3/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0311 - mae: 0.0684 - val_loss: 0.0168 - val_mae: 0.1221
# Epoch 4/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0287 - mae: 0.0569 - val_loss: 0.0040 - val_mae: 0.0504
# Epoch 5/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0266 - mae: 0.0455 - val_loss: 0.0030 - val_mae: 0.0422
# Epoch 6/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0253 - mae: 0.0410 - val_loss: 0.0021 - val_mae: 0.0331
# Epoch 7/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0247 - mae: 0.0383 - val_loss: 0.0020 - val_mae: 0.0314
# Epoch 8/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0242 - mae: 0.0373 - val_loss: 0.0017 - val_mae: 0.0285
# Epoch 9/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0238 - mae: 0.0358 - val_loss: 0.0022 - val_mae: 0.0363
# Epoch 10/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0236 - mae: 0.0372 - val_loss: 0.0062 - val_mae: 0.0677
# Epoch 11/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0234 - mae: 0.0368 - val_loss: 0.0030 - val_mae: 0.0445
# Epoch 12/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0230 - mae: 0.0326 - val_loss: 0.0021 - val_mae: 0.0344
# Epoch 13/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0232 - mae: 0.0381 - val_loss: 0.0029 - val_mae: 0.0427
# Epoch 14/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0230 - mae: 0.0348 - val_loss: 0.0017 - val_mae: 0.0293
# Epoch 15/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0228 - mae: 0.0348 - val_loss: 0.0016 - val_mae: 0.0273
# Epoch 16/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0229 - mae: 0.0362 - val_loss: 0.0034 - val_mae: 0.0473
# Epoch 17/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0229 - mae: 0.0375 - val_loss: 0.0021 - val_mae: 0.0346
# Epoch 18/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0231 - mae: 0.0376 - val_loss: 0.0016 - val_mae: 0.0278
# Epoch 19/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0226 - mae: 0.0330 - val_loss: 0.0060 - val_mae: 0.0685
# Epoch 20/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0226 - mae: 0.0333 - val_loss: 0.0015 - val_mae: 0.0263
# Epoch 21/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0226 - mae: 0.0337 - val_loss: 0.0015 - val_mae: 0.0268
# Epoch 22/50
# 89/89 [==============================] - 1s 10ms/step - loss: 0.0227 - mae: 0.0367 - val_loss: 0.0032 - val_mae: 0.0469
# Epoch 23/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0224 - mae: 0.0349 - val_loss: 0.0015 - val_mae: 0.0270
# Epoch 24/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0225 - mae: 0.0344 - val_loss: 0.0062 - val_mae: 0.0670
# Epoch 25/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0227 - mae: 0.0371 - val_loss: 0.0018 - val_mae: 0.0312
# Epoch 26/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0226 - mae: 0.0338 - val_loss: 0.0024 - val_mae: 0.0385
# Epoch 27/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0224 - mae: 0.0336 - val_loss: 0.0016 - val_mae: 0.0289
# Epoch 28/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0223 - mae: 0.0347 - val_loss: 0.0015 - val_mae: 0.0274
# Epoch 29/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0225 - mae: 0.0386 - val_loss: 0.0033 - val_mae: 0.0472
# Epoch 30/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0224 - mae: 0.0357 - val_loss: 0.0039 - val_mae: 0.0525
# Epoch 31/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0224 - mae: 0.0362 - val_loss: 0.0036 - val_mae: 0.0495
# Epoch 32/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0221 - mae: 0.0336 - val_loss: 0.0025 - val_mae: 0.0393
# Epoch 33/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0235 - mae: 0.0466 - val_loss: 0.0029 - val_mae: 0.0444
# Epoch 34/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0224 - mae: 0.0364 - val_loss: 0.0014 - val_mae: 0.0246
# Epoch 35/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0221 - mae: 0.0336 - val_loss: 0.0014 - val_mae: 0.0246
# Epoch 36/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0227 - mae: 0.0379 - val_loss: 0.0024 - val_mae: 0.0386
# Epoch 37/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0228 - mae: 0.0411 - val_loss: 0.0022 - val_mae: 0.0358
# Epoch 38/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0225 - mae: 0.0373 - val_loss: 0.0226 - val_mae: 0.1309
# Epoch 39/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0228 - mae: 0.0413 - val_loss: 0.0047 - val_mae: 0.0569
# Epoch 40/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0223 - mae: 0.0363 - val_loss: 0.0015 - val_mae: 0.0267
# Epoch 41/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0220 - mae: 0.0339 - val_loss: 0.0016 - val_mae: 0.0290
# Epoch 42/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0222 - mae: 0.0332 - val_loss: 0.0017 - val_mae: 0.0307
# Epoch 43/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0221 - mae: 0.0353 - val_loss: 0.0050 - val_mae: 0.0611
# Epoch 44/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0225 - mae: 0.0379 - val_loss: 0.0014 - val_mae: 0.0245
# Epoch 45/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0225 - mae: 0.0396 - val_loss: 0.0019 - val_mae: 0.0325
# Epoch 46/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0221 - mae: 0.0368 - val_loss: 0.0015 - val_mae: 0.0265
# Epoch 47/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0221 - mae: 0.0367 - val_loss: 0.0026 - val_mae: 0.0415
# Epoch 48/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0221 - mae: 0.0338 - val_loss: 0.0014 - val_mae: 0.0247
# Epoch 49/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0226 - mae: 0.0391 - val_loss: 0.0013 - val_mae: 0.0230
# Epoch 50/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0218 - mae: 0.0309 - val_loss: 0.0189 - val_mae: 0.1315

# %%
MLP_df =pd.DataFrame(history_4.history)
plt.figure(figsize=(9,5))
plt.plot(MLP_df['loss'], label ='Training loss (MSE)', color = 'blue')
plt.plot(MLP_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
plt.xlabel('Mini-batch', fontsize=13)
plt.ylabel('Loss', fontsize=13)
plt.legend(fontsize=13)
# plt.savefig('images/MLP_Model.png', format='png', dpi=1000)
plt.show()

# %%
# Define Conv1D model
conv1D_Model = tf.keras.models.Sequential([
    Input(shape=(lookback, n_features)),
    Conv1D(32, kernel_size=3, activation='relu'),
    Flatten(),
    Dense(5),
    Reshape((5,1))
])

conv1D_Model.compile(optimizer = 'Adam', loss='mse', metrics=["mae"])
conv1D_Model.summary()

np.random.seed(1)
history_5 = conv1D_Model.fit(xtrain,ytrain,batch_size=300,epochs=50,validation_data=(xvalid,yvalid), verbose = 1)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 3, 32)             128
#
#  flatten_2 (Flatten)         (None, 96)                0
#
#  dense_9 (Dense)             (None, 5)                 485
#
#  reshape_2 (Reshape)         (None, 5, 1)              0
#
# =================================================================
# Total params: 613
# Trainable params: 613
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 10/10 [==============================] - 4s 86ms/step - loss: 9.5027 - mae: 2.8257 - val_loss: 21.3505 - val_mae: 4.5645
# Epoch 2/50
# 10/10 [==============================] - 0s 20ms/step - loss: 6.3819 - mae: 2.3118 - val_loss: 13.8016 - val_mae: 3.6653
# Epoch 3/50
# 10/10 [==============================] - 0s 21ms/step - loss: 3.9228 - mae: 1.8030 - val_loss: 7.8164 - val_mae: 2.7511
# Epoch 4/50
# 10/10 [==============================] - 0s 21ms/step - loss: 2.0326 - mae: 1.2829 - val_loss: 3.5316 - val_mae: 1.8325
# Epoch 5/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.8044 - mae: 0.7736 - val_loss: 1.0863 - val_mae: 0.9825
# Epoch 6/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.2189 - mae: 0.3385 - val_loss: 0.1827 - val_mae: 0.3468
# Epoch 7/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0697 - mae: 0.1496 - val_loss: 0.0311 - val_mae: 0.1472
# Epoch 8/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0621 - mae: 0.1470 - val_loss: 0.0133 - val_mae: 0.0958
# Epoch 9/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0553 - mae: 0.1292 - val_loss: 0.0031 - val_mae: 0.0416
# Epoch 10/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0478 - mae: 0.0960 - val_loss: 0.0112 - val_mae: 0.0905
# Epoch 11/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0463 - mae: 0.0855 - val_loss: 0.0185 - val_mae: 0.1233
# Epoch 12/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0460 - mae: 0.0830 - val_loss: 0.0168 - val_mae: 0.1190
# Epoch 13/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0453 - mae: 0.0824 - val_loss: 0.0138 - val_mae: 0.1068
# Epoch 14/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0449 - mae: 0.0829 - val_loss: 0.0119 - val_mae: 0.0974
# Epoch 15/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0446 - mae: 0.0831 - val_loss: 0.0114 - val_mae: 0.0952
# Epoch 16/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0442 - mae: 0.0823 - val_loss: 0.0123 - val_mae: 0.0995
# Epoch 17/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0438 - mae: 0.0812 - val_loss: 0.0128 - val_mae: 0.1020
# Epoch 18/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0434 - mae: 0.0805 - val_loss: 0.0122 - val_mae: 0.0991
# Epoch 19/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0429 - mae: 0.0803 - val_loss: 0.0115 - val_mae: 0.0958
# Epoch 20/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0425 - mae: 0.0797 - val_loss: 0.0115 - val_mae: 0.0961
# Epoch 21/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0420 - mae: 0.0789 - val_loss: 0.0115 - val_mae: 0.0957
# Epoch 22/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0414 - mae: 0.0782 - val_loss: 0.0113 - val_mae: 0.0951
# Epoch 23/50
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0409 - mae: 0.0776 - val_loss: 0.0111 - val_mae: 0.0942
# Epoch 24/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0403 - mae: 0.0769 - val_loss: 0.0105 - val_mae: 0.0910
# Epoch 25/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0397 - mae: 0.0763 - val_loss: 0.0106 - val_mae: 0.0916
# Epoch 26/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0391 - mae: 0.0752 - val_loss: 0.0110 - val_mae: 0.0935
# Epoch 27/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0386 - mae: 0.0743 - val_loss: 0.0109 - val_mae: 0.0932
# Epoch 28/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0380 - mae: 0.0734 - val_loss: 0.0107 - val_mae: 0.0918
# Epoch 29/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0375 - mae: 0.0732 - val_loss: 0.0098 - val_mae: 0.0872
# Epoch 30/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0369 - mae: 0.0726 - val_loss: 0.0101 - val_mae: 0.0888
# Epoch 31/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0364 - mae: 0.0716 - val_loss: 0.0104 - val_mae: 0.0905
# Epoch 32/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0359 - mae: 0.0708 - val_loss: 0.0102 - val_mae: 0.0896
# Epoch 33/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0354 - mae: 0.0700 - val_loss: 0.0099 - val_mae: 0.0880
# Epoch 34/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0349 - mae: 0.0695 - val_loss: 0.0094 - val_mae: 0.0855
# Epoch 35/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0345 - mae: 0.0690 - val_loss: 0.0092 - val_mae: 0.0841
# Epoch 36/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0341 - mae: 0.0683 - val_loss: 0.0092 - val_mae: 0.0844
# Epoch 37/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0337 - mae: 0.0675 - val_loss: 0.0091 - val_mae: 0.0839
# Epoch 38/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0333 - mae: 0.0665 - val_loss: 0.0094 - val_mae: 0.0855
# Epoch 39/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0330 - mae: 0.0661 - val_loss: 0.0086 - val_mae: 0.0809
# Epoch 40/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0326 - mae: 0.0658 - val_loss: 0.0083 - val_mae: 0.0793
# Epoch 41/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0322 - mae: 0.0646 - val_loss: 0.0084 - val_mae: 0.0797
# Epoch 42/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0318 - mae: 0.0634 - val_loss: 0.0080 - val_mae: 0.0779
# Epoch 43/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0314 - mae: 0.0626 - val_loss: 0.0077 - val_mae: 0.0759
# Epoch 44/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0310 - mae: 0.0614 - val_loss: 0.0074 - val_mae: 0.0743
# Epoch 45/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0305 - mae: 0.0593 - val_loss: 0.0072 - val_mae: 0.0727
# Epoch 46/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0300 - mae: 0.0573 - val_loss: 0.0068 - val_mae: 0.0703
# Epoch 47/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0295 - mae: 0.0548 - val_loss: 0.0054 - val_mae: 0.0608
# Epoch 48/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0290 - mae: 0.0512 - val_loss: 0.0045 - val_mae: 0.0538
# Epoch 49/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0283 - mae: 0.0473 - val_loss: 0.0043 - val_mae: 0.0529
# Epoch 50/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0277 - mae: 0.0433 - val_loss: 0.0035 - val_mae: 0.0466

# %%
conv1D_df = pd.DataFrame(history_5.history)
print('')
plt.figure(figsize=(9,5))
plt.plot(conv1D_df['loss'], label ='Training loss (MSE)', color = 'blue')
plt.plot(conv1D_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
plt.xlabel('Mini-batch', fontsize=13)
plt.ylabel('Loss', fontsize=13)
plt.legend(fontsize=13)
# plt.savefig('images/conv1D_Model.png', format='png', dpi=1000)
plt.show()

# %% [markdown]
# ## Fitting All The Models

# %% [markdown]
# ## Predictions
# Now we will use our model to make predictions.

# %%
real_pred1 = RNN.predict(xtest)
real_pred2 = LSTM_Model.predict(xtest)
real_pred3 = GRU_Model.predict(xtest)
real_pred4 = MLP_Model.predict(xtest)
real_pred5 = conv1D_Model.predict(xtest)
# Out:
# 30/30 [==============================] - 1s 6ms/step
# 30/30 [==============================] - 2s 9ms/step
# 30/30 [==============================] - 2s 10ms/step
# 30/30 [==============================] - 0s 5ms/step
# 30/30 [==============================] - 0s 6ms/step

# %%
real_pred1.shape,real_pred2.shape,real_pred3.shape,real_pred4.shape,real_pred5.shape
# Out:
# ((949, 5, 1), (949, 5), (949, 5, 1), (949, 5), (949, 5, 1))

# %%
# Combined Models
Pred_Data = pd.DataFrame({
    'RNN': real_pred1[:,0].flatten(),
    'LSTM': real_pred2[:,0].flatten(),
    'GRU': real_pred3[:,0].flatten(),
    'MLP': real_pred4[:,0].flatten(),  
    'conv1D': real_pred5[:,0].flatten(),  
    'Actual Rate': xtest[:,0].flatten()
})

Pred_Data.head()
# Out:
#         RNN      LSTM       GRU       MLP    conv1D  Actual Rate
# 0  5.877832  5.891604  5.960213  5.786146  5.875463       5.9385
# 1  5.877858  5.891500  5.918052  5.786459  5.876340       5.8972
# 2  5.839632  5.844124  5.939600  5.760747  5.864986       5.9183
# 3  5.832038  5.839060  5.939600  5.749440  5.855043       5.9183
# 4  5.832096  5.842000  5.939600  5.742966  5.852546       5.9183

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(19,10))

axs[0,0].plot(RNN_df['loss'], label ='Training ', color = 'blue')
axs[0,0].plot(RNN_df['val_loss'], label='Validation ', color = 'orange')
axs[0,0].set_title('RNN (Loss / Mean Square Error)')

axs[0,1].plot(LSTM_df['loss'], label ='Training loss (MSE)', color = 'blue')
axs[0,1].plot(LSTM_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
axs[0,1].set_title('LSTM (Loss / Mean Square Error)')

axs[0,2].plot(GRU_df['loss'], label ='Training ', color = 'blue')
axs[0,2].plot(GRU_df['val_loss'], label='Validation ', color = 'orange')
axs[0,2].set_title('GRU (Loss / Mean Square Error)')

axs[1,0].plot(MLP_df['loss'], label ='Training ', color = 'blue')
axs[1,0].plot(MLP_df['val_loss'], label='Validation ', color = 'orange')
axs[1,0].set_title('MLP (Loss / Mean Square Error)')

axs[1,1].plot(conv1D_df['loss'], label ='Training', color = 'blue')
axs[1,1].plot(conv1D_df['val_loss'], label='Validation ', color = 'orange')
axs[1,1].set_title('conv1D (Loss / Mean Square Error)')

axs[1,2].set_title('Loss Function')
# Add a blank subplot to fill the last space in the grid
axs[1,2].axis('off')
#Add legend to all plots
axs[0,0].legend(loc='upper left')
axs[0,1].legend(loc='upper left')
axs[0,2].legend(loc='upper left')
axs[1,0].legend(loc='upper left')
axs[1,1].legend(loc='upper left')
# Add a shared x-axis label to the bottom row of subplots
for ax in axs[1,:]:
    ax.set_xlabel('Epochs', fontsize=13)

# Add a shared y-axis label to the left column of subplots
for ax in axs[:,0]:
    ax.set_ylabel('Loss', fontsize=13)
    


    
plt.tight_layout()
plt.savefig('../images/lossfnx_usd_relu.png', format='png', dpi=1000)
plt.show()

# %% [markdown]
# ## Combined Plots

# %%
plt.figure(figsize=(19,8))
plt.plot(Pred_Data['RNN'], color = 'red', label = 'RNN')
plt.plot(Pred_Data['LSTM'], color = 'green', label = 'LSTM')
plt.plot(Pred_Data['GRU'], color = 'orange', label = 'GRU')
plt.plot(Pred_Data['MLP'], color = 'maroon', label = 'MLP')
plt.plot(Pred_Data['conv1D'], color = 'black', label = 'conv1D')
plt.plot(xtest[:,0,0].flatten(), color = 'blue', label = 'Actual Rate')
plt.xlabel('Time (days)', fontsize=13)
plt.ylabel('Loss', fontsize=13)
plt.legend(fontsize=13)
plt.savefig('images/Combined1.png', format='png', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15,8))

axs[0,0].plot(Pred_Data['RNN'], color='red', label='RNN')
axs[0,0].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[0,0].set_title('RNN vs Actual Rate')

axs[0,1].plot(Pred_Data['LSTM'], color='green', label='LSTM')
axs[0,1].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[0,1].set_title('LSTM vs Actual Rate')

axs[0,2].plot(Pred_Data['GRU'], color='orange', label='GRU')
axs[0,2].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[0,2].set_title('GRU vs Actual Rate')

axs[1,0].plot(Pred_Data['MLP'], color='maroon', label='MLP')
axs[1,0].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[1,0].set_title('MLP vs Actual Rate')

axs[1,1].plot(Pred_Data['conv1D'], color='navy', label='conv1D')
axs[1,1].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[1,1].set_title('conv1D vs Actual Rate')

axs[1,2].plot(Pred_Data['RNN'], color = 'red', label = 'RNN')
axs[1,2].plot(Pred_Data['LSTM'], color = 'green', label = 'LSTM')
axs[1,2].plot(Pred_Data['GRU'], color = 'orange', label = 'GRU')
axs[1,2].plot(Pred_Data['MLP'], color = 'maroon', label = 'MLP')
axs[1,2].plot(Pred_Data['conv1D'], color = 'black', label = 'conv1D')
axs[1,2].plot(xtest[:,0,0].flatten(), color = 'blue', label = 'Actual Rate')

axs[1,2].set_title('Combined Plots')
# Add a blank subplot to fill the last space in the grid
axs[1,2].axis('off')

axs[0,0].legend(loc='upper left')
axs[0,1].legend(loc='upper left')
axs[0,2].legend(loc='upper left')
axs[1,0].legend(loc='upper left')
axs[1,1].legend(loc='upper left')
axs[1,2].legend(loc='upper left')
# Add a shared x-axis label to the bottom row of subplots
for ax in axs[1,:]:
    ax.set_xlabel('Time (days)', fontsize=13)

# Add a shared y-axis label to the left column of subplots
for ax in axs[:,0]:
    ax.set_ylabel('GHS/USD Rates', fontsize=13)
    

plt.tight_layout()
plt.savefig('images/Combined2.png', format='png', dpi=1000)
plt.show()

# %%
# plt.figure(figsize=(19,8))
# plt.plot(Pred_Data['RNN'], color='red', label='RNN')
# plt.plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
# plt.xlabel('Time (days)', fontsize=13)
# plt.ylabel('Exchange Rate', fontsize=13)
# plt.title('RNN vs Actual Rate', fontsize=13)
# plt.legend(fontsize=13,loc='upper left', ncol=2)
# plt.show()

# %%
# Assuming xtest is the test data and has shape (num_samples, num_timesteps, num_features)
rnn_pred = RNN.predict(xtest)
lstm_pred = LSTM_Model.predict(xtest)
gru_pred = GRU_Model.predict(xtest)
mlp_pred = MLP_Model.predict(xtest)
conv1d_pred = conv1D_Model.predict(xtest)
# Out:
# 30/30 [==============================] - 0s 3ms/step
# 30/30 [==============================] - 0s 5ms/step
# 30/30 [==============================] - 0s 5ms/step
# 30/30 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 3ms/step

# %%
# Combined Models
Pred_Data = pd.DataFrame({
    'RNN': rnn_pred[:,0].flatten(),
    'LSTM': lstm_pred[:,0].flatten(),
    'GRU': gru_pred[:,0].flatten(),
    'MLP': mlp_pred[:,0].flatten(),  # fixed typo here
    'conv1D': conv1d_pred[:,0].flatten(),  # fixed typo here
    'Actual Rate': xtest[:,0].flatten()
})

Pred_Data.head()
# Out:
#         RNN      LSTM       GRU       MLP    conv1D  Actual Rate
# 0  5.948361  5.874539  5.994513  5.904864  5.905824       5.9385
# 1  5.948372  5.870703  5.951940  5.909400  5.909331       5.8972
# 2  5.908739  5.859576  5.973697  5.880883  5.900522       5.9183
# 3  5.901913  5.853568  5.973697  5.861912  5.892575       5.9183
# 4  5.901998  5.847326  5.973697  5.855451  5.887012       5.9183

# %%
actuals = ytest.reshape(-1, 1)
actuals.shape,Pred_Data.shape
# Out:
# ((949, 1), (949, 6))

# %%
# print('')
# plt.figure(figsize=(10,5))
# plt.plot(actuals, label="Actual Rate", color = 'blue')
# plt.plot(Pred_Data['RNN'], label="RNN", color = 'red')
# plt.xlabel('Time (days)', fontsize=13)
# plt.ylabel('Rate', fontsize=13)
# plt.legend(fontsize=13)
# plt.show()

# %%
print('The the mean absolute error committed by the standard RNN model is: ', mean_absolute_error(actuals,Pred_Data['RNN']))
# Out:
# The the mean absolute error committed by the standard RNN model is:  0.03953548379542329

# %%
# Evaluate RNN predictions
rnn_mae = mean_absolute_error(ytest, Pred_Data['RNN'])
rnn_mse = mean_squared_error(ytest, Pred_Data['RNN'])
rnn_rmse = np.sqrt(rnn_mse)
rnn_r2 = r2_score(ytest, Pred_Data['RNN'])

# Evaluate LSTM predictions
lstm_mae = mean_absolute_error(ytest, Pred_Data['LSTM'])
lstm_mse = mean_squared_error(ytest, Pred_Data['LSTM'])
lstm_rmse = np.sqrt(lstm_mse)
lstm_r2 = r2_score(ytest, Pred_Data['LSTM'])

# Evaluate GRU predictions
gru_mae = mean_absolute_error(ytest, Pred_Data['GRU'])
gru_mse = mean_squared_error(ytest, Pred_Data['GRU'])
gru_rmse = np.sqrt(gru_mse)
gru_r2 = r2_score(ytest, Pred_Data['GRU'])

# Evaluate MLP predictions
mlp_mae = mean_absolute_error(ytest, Pred_Data['MLP'])
mlp_mse = mean_squared_error(ytest, Pred_Data['MLP'])
mlp_rmse = np.sqrt(mlp_mse)
mlp_r2 = r2_score(ytest, Pred_Data['MLP'])

# Evaluate Conv1D predictions
conv1d_mae = mean_absolute_error(ytest, Pred_Data['conv1D'])
conv1d_mse = mean_squared_error(ytest, Pred_Data['conv1D'])
conv1d_rmse = np.sqrt(conv1d_mse)
conv1d_r2 = r2_score(ytest, Pred_Data['conv1D'])

# %%
print("RNN Evaluation Metrics:")
print(f"MAE: {rnn_mae:.4f}, MSE: {rnn_mse:.4f}, RMSE: {rnn_rmse:.4f}, R2: {rnn_r2:.4f}\n")

print("LSTM Evaluation Metrics:")
print(f"MAE: {lstm_mae:.4f}, MSE: {lstm_mse:.4f}, RMSE: {lstm_rmse:.4f}, R2: {lstm_r2:.4f}\n")

print("GRU Evaluation Metrics:")
print(f"MAE: {gru_mae:.4f}, MSE: {gru_mse:.4f}, RMSE: {gru_rmse:.4f}, R2: {gru_r2:.4f}\n")

print("MLP Evaluation Metrics:")
print(f"MAE: {mlp_mae:.4f}, MSE: {mlp_mse:.4f}, RMSE: {mlp_rmse:.4f}, R2: {mlp_r2:.4f}\n")

print("Conv1D Evaluation Metrics:")
print(f"MAE: {conv1d_mae:.4f}, MSE: {conv1d_mse:.4f}, RMSE: {conv1d_rmse:.4f}, R2: {conv1d_r2:.4f}\n")
# Out:
# RNN Evaluation Metrics:
# MAE: 0.0395, MSE: 0.0023, RMSE: 0.0479, R2: 0.9904
#
# LSTM Evaluation Metrics:
# MAE: 0.0806, MSE: 0.0086, RMSE: 0.0930, R2: 0.9638
#
# GRU Evaluation Metrics:
# MAE: 0.0787, MSE: 0.0105, RMSE: 0.1022, R2: 0.9562
#
# MLP Evaluation Metrics:
# MAE: 0.0294, MSE: 0.0017, RMSE: 0.0415, R2: 0.9928
#
# Conv1D Evaluation Metrics:
# MAE: 0.0422, MSE: 0.0035, RMSE: 0.0588, R2: 0.9855

# %%
# Create a DataFrame with evaluation metrics
Results = pd.DataFrame({'MAE': [rnn_mae, lstm_mae, gru_mae, mlp_mae, conv1d_mae],
                        'MSE': [rnn_mse, lstm_mse, gru_mse, mlp_mse, conv1d_mse],
                        'RMSE': [rnn_rmse, lstm_rmse, gru_rmse, mlp_rmse, conv1d_rmse],
                        'R2': [rnn_r2, lstm_r2, gru_r2, mlp_r2, conv1d_r2]},
                       index=['RNN', 'LSTM', 'GRU', 'MLP', 'Conv1D'])
Results
# Out:
#              MAE       MSE      RMSE        R2
# RNN     0.039535  0.002296  0.047919  0.990384
# LSTM    0.080556  0.008647  0.092991  0.963789
# GRU     0.078681  0.010455  0.102249  0.956220
# MLP     0.029373  0.001719  0.041463  0.992801
# Conv1D  0.042233  0.003455  0.058780  0.985532
