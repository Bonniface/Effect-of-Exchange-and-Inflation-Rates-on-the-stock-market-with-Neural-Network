# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error

# %%
# Imported Interbank FX Rates Historical.csv
Interbank_FX_Rates_Historical = pd.read_csv('./datasets/Interbank FX Rates Historical.csv')
# Deleted columns Currency, Currency Pair, Buying
Interbank_FX_Rates_Historical.drop(['Currency', 'Currency Pair', 'Buying','Mid Rate'], axis=1, inplace=True)
# Renamed columns GBPGHS
Interbank_FX_Rates_Historical.rename(columns={'Selling': 'GBPGHS'}, inplace=True)

# %%
# Imported Interbank FX Rates Historical (1).csv
Interbank_FX_Rates_Historical_1 = pd.read_csv('./datasets/Interbank FX Rates Historical (1).csv')
# Deleted columns Currency, Currency Pair, Buying
Interbank_FX_Rates_Historical_1.drop(['Currency', 'Currency Pair', 'Buying','Mid Rate'], axis=1, inplace=True)
# Renamed columns USDGHS
Interbank_FX_Rates_Historical_1.rename(columns={'Selling': 'USDGHS'}, inplace=True)

# %%
# Merged Interbank_FX_Rates_Historical_1 and Interbank_FX_Rates_Historical into df3
temp_df = Interbank_FX_Rates_Historical.drop_duplicates(subset=['Date']) # Remove duplicates so lookup merge only returns first match
df = Interbank_FX_Rates_Historical_1.merge(temp_df, left_on=['Date'], right_on=['Date'], how='left', suffixes=['_Interbank_FX_Rates_Historical_1', '_Interbank_FX_Rates_Historical'])
df.head()
# Out:
#           Date  USDGHS  GBPGHS
# 0  31 Dec 2020  7.8787  5.7631
# 1  30 Dec 2020  7.8087  5.7371
# 2  29 Dec 2020  7.7383  5.7351
# 3  24 Dec 2020  7.7779  5.7351
# 4  23 Dec 2020  7.7344  5.7241

# %%
# Check for missing values
print('missing values:', df.isnull().sum().sort_values(ascending = False))
# Out:
# missing values: Date      0
# USDGHS    0
# GBPGHS    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3226 entries, 0 to 3225
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3226 non-null   object
#  1   USDGHS  3226 non-null   object
#  2   GBPGHS  3226 non-null   object
# dtypes: object(3)
# memory usage: 100.8+ KB

# %%
df['USDGHS'] = pd.to_numeric(df['USDGHS'], errors='coerce')
df['GBPGHS'] = pd.to_numeric(df['GBPGHS'], errors='coerce')
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
# Resample the DataFrame to a daily frequency and forward-fill missing values
df = df.resample('D').ffill()
df = df.fillna(method='bfill')
df.describe()
# Out:
#             USDGHS       GBPGHS
# count  4748.000000  4748.000000
# mean      4.320325     3.040635
# std       1.846412     1.547481
# min       0.000000     0.000000
# 25%       2.454700     1.522400
# 50%       4.878600     3.011850
# 75%       5.922800     4.404125
# max       7.878700     5.763100

# %%
df_plot = df.copy()
df.head()
# Out:
#             USDGHS  GBPGHS
# Date
# 2008-01-02  1.9427  0.9799
# 2008-01-03  1.9394  0.9799
# 2008-01-04  1.9309  0.9798
# 2008-01-05  1.9309  0.9798
# 2008-01-06  1.9309  0.9798

# %%
# Let's see a historical view of the closing Rate
df_plot['USDGHS'].plot(legend=True, figsize=(10,4))
df_plot['GBPGHS'].plot(legend=True, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Let's go ahead and plot out several moving averages
MA_day = [10,50,200]

for ma in MA_day:
    column_name = 'MA for %s days' %(str(ma))
    df_plot[column_name] = df_plot['USDGHS'].rolling(window=ma).mean()

# %%
df_plot = df_plot[['USDGHS','MA for 10 days','MA for 50 days','MA for 200 days']].plot(subplots=False,figsize=(19,8))

# %%
USDGHS = df['USDGHS']
USDGHS.to_csv('datasets/USDGHS.csv')
USDGHS.head()
# Out:
# Date
# 2008-01-02    1.9427
# 2008-01-03    1.9394
# 2008-01-04    1.9309
# 2008-01-05    1.9309
# 2008-01-06    1.9309
# Freq: D, Name: USDGHS, dtype: float64

# %% [markdown]
# It is not necessary to check for autocorrelation in time series before using LSTM. However, it is important to check for autocorrelation in time series data before using any time series model. Autocorrelation is a measure of the correlation between the values of a time series at different points in time. If there is autocorrelation in the data, it means that the values of the time series at one point in time are correlated with the values at other points in time. This can lead to biased estimates of the model parameters and can affect the accuracy of the model predictions

# %%
from statsmodels.graphics import tsaplots
import matplotlib.pyplot as plt

#plot autocorrelation function
fig = tsaplots.plot_acf(df["USDGHS"], lags=12)
fig = tsaplots.plot_acf(df["GBPGHS"], lags=12)
plt.show()

# %%
print('the shape of the  dataset is ', USDGHS.shape)
# Out:
# the shape of the  dataset is  (4748,)

# %% [markdown]
# ### Transforming the time series into well labelled training and testing dataset
#
# We will use the following function to transform time series into well labelled braining training and target samples. i.e we transform out input into a tuple (n_samples,n_timesteps,n_features)

# %%
def Model_data_setup(data, lookback, delay, min_index, max_index):
    """
    data:     Shape (n_samples, n_features). First column is the time series, other columns are the features.
              If there is only one column, it is assumed to be the time series data.
    lookback: Number of time steps in the Model >= 1
    delay:    The number of time steps to predict >= 1.
    min_index,max_index: The starting and ending indices of the time series portion to construct the data.
                         Allows constructing validation and test sets from the series in proper shape
    Returns: A tuple (x, y) of numpy arrays where x is in shape (n_samples, n_timesteps, n_features) and 
             y is in shape (n_samples, delay). y is an array of target arrays each of size delay. To forecast 
             a single value n timesteps ahead, set delay = n and take the last element of the forecast array.
    """
    if data.ndim == 1:
        data = np.expand_dims(data, axis=1)
    n_samples = max_index - lookback - delay + 1
    x_shape = (n_samples, lookback, data.shape[1])
    x = np.zeros(x_shape)
    y_shape = (n_samples, delay)
    y = np.zeros(y_shape)

    for i in range(n_samples):
        start_index = i + min_index
        end_index = start_index + lookback
        x[i,:,:] = data[start_index:end_index,:]
        y[i,:] = data[end_index + delay - 1, 0]

    return x, y

# %%
xdata, ydata = Model_data_setup(USDGHS.values, lookback=5, delay=1, min_index=0, max_index=len(USDGHS)-1)

# %% [markdown]
# ### Splitting the dataset into the training and testing sets
#
# We are splitting the dataset of normalized stock Rates into 80$\%$ and 20$\%$ for training and testing respectively. 20 $\%$ of training set will be assigned for validation at later stage.

# %%
#Specifying the sizes of training and testing datasets.
train_size = int(len(xdata)*0.6) # 2416#
valid_size = int(len(xdata)*0.2) #605#
test_size = len(xdata) - train_size-valid_size #355#

#Splitting the dataset into trainig, validation and testing.
xtrain, xvalid, xtest = xdata[0:train_size,:], xdata[train_size:train_size+valid_size,:], xdata[train_size+valid_size:len(xdata),:]
ytrain, yvalid, ytest = ydata[0:train_size,:], ydata[train_size:train_size+valid_size,:], ydata[train_size+valid_size:len(ydata),:]

print('The shape of the training sample is: ', xtrain.shape)
print('The shape of the validation sample is: ', xvalid.shape)
print('The shape of the testing sample is: ', xtest.shape)
print('The shape of the training target is: ', ytrain.shape)
print('The shape of the validation target is: ', yvalid.shape)
print('The shape of the testing target is: ', ytest.shape)
# Out:
# The shape of the training sample is:  (2845, 5, 1)
# The shape of the validation sample is:  (948, 5, 1)
# The shape of the testing sample is:  (949, 5, 1)
# The shape of the training target is:  (2845, 1)
# The shape of the validation target is:  (948, 1)
# The shape of the testing target is:  (949, 1)

# %%
xtrain = np.reshape(xtrain, (xtrain.shape[0], xtrain.shape[1], -1))
xvalid = np.reshape(xvalid, (xvalid.shape[0], xvalid.shape[1], -1))
xtest = np.reshape(xtest, (xtest.shape[0], xtest.shape[1], -1))
xtrain.shape,xvalid.shape,xtest.shape
# Out:
# ((2845, 5, 1), (948, 5, 1), (949, 5, 1))

# %% [markdown]
# ## Neural Networks Models

# %%
from keras.models import Sequential
from keras.models import Model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, SimpleRNN, LSTM,GRU,Conv1D, ConvLSTM2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Reshape
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# The RNNs have a feedback mechanism that allows them to take into account the previous inputs in the sequence while making predictions. This feedback loop creates a kind of memory within the network, which is why RNNs are well-suited for sequential data. The mathematical representation of an RNN is:
#
# \begin{equation}
# h_t = f(W_{hh}h_{t-1} + W_{xh}x_t + b_h)
# \end{equation}
#
# where $h_t$ is the hidden state at time $t$, $x_t$ is the input at time $t$, $W_{hh}$ is the weight matrix for the hidden-to-hidden connections, $W_{xh}$ is the weight matrix for the input-to-hidden connections, $b_h$ is the bias term, and $f$ is an activation function.

# %% [markdown]
# LSTM networks are a type of RNN that are designed to address the vanishing gradient problem that can occur in traditional RNNs. LSTM networks use memory cells and gates to selectively remember or forget information from previous inputs. The mathematical representation of an LSTM network is:
#
# \begin{align}
# f_t &= \sigma(W_f \cdot [h_{t-1}, x_t] + b_f) \\
# i_t &= \sigma(W_i \cdot [h_{t-1}, x_t] + b_i) \\
# o_t &= \sigma(W_o \cdot [h_{t-1}, x_t] + b_o) \\
# \tilde{C}t &= \tanh(W_C \cdot [h{t-1}, x_t] + b_C) \\
# C_t &= f_t * C_{t-1} + i_t * \tilde{C}_t \\
# h_t &= o_t * \tanh(C_t)
# \end{align}
#
# where $f_t$ is the forget gate, $i_t$ is the input gate, $o_t$ is the output gate, $\tilde{C}_t$ is the candidate cell state, $C_t$ is the cell state, and $h_t$ is the hidden state. $W_f$, $W_i$, $W_o$, and $W_C$ are the weight matrices, and $b_f$, $b_i$, $b_o$, and $b_C$ are the bias terms. $\sigma$ is the sigmoid activation function, and $\tanh$ is the hyperbolic tangent activation function.

# %% [markdown]
# Let's consider a sequence of two-dimensional data, represented as a tensor $X$ of shape $(num_timesteps, height, width, channels)$. At each time step $t$, the input $X[t]$ is processed by a ConvLSTM cell, which consists of several operations.
#
# First, the cell applies a convolution operation to the input $X[t]$ and the previous hidden state $H[t-1]$, with a set of filters $W_x$ and $W_h$, respectively. The output of this convolution is a set of feature maps $F[t]$:
#
# $$F[t] = \text{Conv}(X[t], W_x) + \text{Conv}(H[t-1], W_h)$$
#
# Next, the cell applies several gating mechanisms to control the flow of information through the network. Specifically, it computes three gates: the input gate $i[t]$, the forget gate $f[t]$, and the output gate $o[t]$:
#
# \begin{align*}
# i[t] &= \sigma(\text{Conv}(X[t], W_i) + \text{Conv}(H[t-1], U_i)) \\
# f[t] &= \sigma(\text{Conv}(X[t], W_f) + \text{Conv}(H[t-1], U_f)) \\
# o[t] &= \sigma(\text{Conv}(X[t], W_o) + \text{Conv}(H[t-1], U_o))
# \end{align*}
#
# where $\sigma$ represents the sigmoid activation function, and $W_i$, $W_f$, $W_o$, $U_i$, $U_f$, and $U_o$ are the weights for the convolutional filters used to compute each gate.
#
# These gates control which information is passed through the cell, and which information is discarded. The input gate $i[t]$ determines how much of the new input $F[t]$ is added to the memory cell $C[t]$, which stores the current state of the cell:
#
# $$C[t] = i[t] \cdot \tanh(\text{Conv}(X[t], W_c) + \text{Conv}(H[t-1], U_c)) + f[t] \cdot C[t-1]$$
#
# where $\tanh$ represents the hyperbolic tangent activation function, and $W_c$ and $U_c$ are the weights for the convolutional filters used to compute the cell state.
#
# Finally, the output gate $o[t]$ determines the output of the cell:
#
# $$H[t] = o[t] \cdot \tanh(C[t])$$
#
# where $H[t]$ is the output of the cell at time ste

# %%
n_features = USDGHS.shape
lr = 0.0016#Learning rate
units = 16 #Number hidden units
batch_size=64
lookback = 5
delay = 1
min_index = 0
max_index = USDGHS.shape[0] - 1

# Define the number of features in the input data
n_features = 1  # We only have one feature, which is the USDGHS exchange rate

# Convert the data into the required format for the model
xdata, ydata = Model_data_setup(USDGHS.values.reshape(-1, 1), lookback, delay, min_index, max_index)

# %% [markdown]
# RNN model using the Sequential class from the `tf.keras.models` module. The model consists of three layers: an input layer, a SimpleRNN layer, and a Dense layer.
#
# The Input layer specifies the shape of the input data, which is a 3D tensor with shape `(n_timesteps, n_features)` where `n_timesteps` is the number of time steps in each input sequence and n_features is the number of features in each time step.
#
# The SimpleRNN layer is a type of RNN layer that uses the recurrent activation function tanh by default. It has 64 units and uses the `relu` activation function. This layer takes the input sequences as input and outputs a sequence of hidden states.
#
# The Dense layer is a fully connected layer that takes the last hidden state from the SimpleRNN layer and outputs a single value, which is the predicted value for the next time step.

# %%
# Define RNN model
RNN = Sequential()
RNN.add(SimpleRNN(units, activation='relu', input_shape=(lookback, n_features), return_sequences=False, recurrent_dropout=0.3))
RNN.add(Dense(5))
RNN.add(Reshape((5, 1)))

RNN.compile(optimizer='Adam', loss='mse', metrics=['mae'])
RNN.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 16)                288
#
#  dense_13 (Dense)            (None, 5)                 85
#
#  reshape_1 (Reshape)         (None, 5, 1)              0
#
# =================================================================
# Total params: 373
# Trainable params: 373
# Non-trainable params: 0
# _________________________________________________________________

# %%
LSTM_Model = tf.keras.models.Sequential([
    Input(shape=(lookback, n_features)),
    LSTM(32, activation='relu', return_sequences=True),
    LSTM(32, activation='relu'),
    Dense(5)
    # Reshape((5, 1))
])

LSTM_Model.compile(loss='mse', optimizer='Adam' , metrics=["mae"])
LSTM_Model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 5, 32)             4352
#
#  lstm_7 (LSTM)               (None, 32)                8320
#
#  dense_14 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 12,837
# Trainable params: 12,837
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define GRU model
GRU_Model = tf.keras.models.Sequential([
    Input(shape=(lookback, n_features)),
    GRU(128, return_sequences=True),
    Dense(5),
    Dense(1)
])

GRU_Model.compile(optimizer = 'Adam', loss='mse', metrics=["mae"])
GRU_Model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 5, 128)            50304
#
#  dense_20 (Dense)            (None, 5, 5)              645
#
#  dense_21 (Dense)            (None, 5, 1)              6
#
# =================================================================
# Total params: 50,955
# Trainable params: 50,955
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define MLP model
MLP_Model = tf.keras.models.Sequential([
    Input(shape=(lookback, n_features)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(5)
    # Reshape((5,1))
])

MLP_Model.compile(optimizer = 'Adam', loss='mse', metrics=["mae"])
MLP_Model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 5)                 0
#
#  dense_16 (Dense)            (None, 64)                384
#
#  dense_17 (Dense)            (None, 32)                2080
#
#  dense_18 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 2,629
# Trainable params: 2,629
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define Conv1D model
conv1D_Model = tf.keras.models.Sequential([
    Input(shape=(lookback, n_features)),
    Conv1D(32, kernel_size=3, activation='relu'),
    Flatten(),
    Dense(5, activation='relu'),
    Reshape((5,1))
])

conv1D_Model.compile(optimizer = 'Adam', loss='mse', metrics=["mae"])
conv1D_Model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 3, 32)             128
#
#  flatten_5 (Flatten)         (None, 96)                0
#
#  dense_22 (Dense)            (None, 5)                 485
#
#  reshape_2 (Reshape)         (None, 5, 1)              0
#
# =================================================================
# Total params: 613
# Trainable params: 613
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fitting All The Models

# %%
np.random.seed(123)
history_1=RNN.fit(xtrain,ytrain, validation_data=(xvalid,yvalid), epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 89/89 [==============================] - 4s 12ms/step - loss: 6.2054 - mae: 2.1158 - val_loss: 5.7951 - val_mae: 2.2070
# Epoch 2/50
# 89/89 [==============================] - 1s 6ms/step - loss: 1.6201 - mae: 0.9557 - val_loss: 1.9512 - val_mae: 1.2851
# Epoch 3/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.8137 - mae: 0.6591 - val_loss: 1.8118 - val_mae: 1.2803
# Epoch 4/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.4705 - mae: 0.4916 - val_loss: 1.2441 - val_mae: 1.0520
# Epoch 5/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.3478 - mae: 0.4166 - val_loss: 1.0412 - val_mae: 0.9504
# Epoch 6/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.2626 - mae: 0.3511 - val_loss: 0.8455 - val_mae: 0.8549
# Epoch 7/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.1949 - mae: 0.3004 - val_loss: 0.5822 - val_mae: 0.7036
# Epoch 8/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.1497 - mae: 0.2592 - val_loss: 0.4842 - val_mae: 0.6378
# Epoch 9/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.1225 - mae: 0.2273 - val_loss: 0.3656 - val_mae: 0.5383
# Epoch 10/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.1040 - mae: 0.2012 - val_loss: 0.2756 - val_mae: 0.4518
# Epoch 11/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0839 - mae: 0.1767 - val_loss: 0.2264 - val_mae: 0.4044
# Epoch 12/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0718 - mae: 0.1571 - val_loss: 0.1782 - val_mae: 0.3422
# Epoch 13/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0625 - mae: 0.1390 - val_loss: 0.1493 - val_mae: 0.3091
# Epoch 14/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0569 - mae: 0.1275 - val_loss: 0.1040 - val_mae: 0.2430
# Epoch 15/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0515 - mae: 0.1146 - val_loss: 0.0956 - val_mae: 0.2355
# Epoch 16/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0481 - mae: 0.1050 - val_loss: 0.0801 - val_mae: 0.2126
# Epoch 17/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0443 - mae: 0.0986 - val_loss: 0.0495 - val_mae: 0.1604
# Epoch 18/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0428 - mae: 0.0918 - val_loss: 0.0526 - val_mae: 0.1717
# Epoch 19/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0396 - mae: 0.0849 - val_loss: 0.0520 - val_mae: 0.1743
# Epoch 20/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0396 - mae: 0.0826 - val_loss: 0.0368 - val_mae: 0.1390
# Epoch 21/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0395 - mae: 0.0803 - val_loss: 0.0350 - val_mae: 0.1348
# Epoch 22/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0373 - mae: 0.0759 - val_loss: 0.0210 - val_mae: 0.1010
# Epoch 23/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0368 - mae: 0.0729 - val_loss: 0.0195 - val_mae: 0.0937
# Epoch 24/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0362 - mae: 0.0709 - val_loss: 0.0192 - val_mae: 0.0946
# Epoch 25/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0355 - mae: 0.0705 - val_loss: 0.0111 - val_mae: 0.0689
# Epoch 26/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0350 - mae: 0.0662 - val_loss: 0.0122 - val_mae: 0.0745
# Epoch 27/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0342 - mae: 0.0648 - val_loss: 0.0109 - val_mae: 0.0699
# Epoch 28/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0313 - mae: 0.0608 - val_loss: 0.0118 - val_mae: 0.0725
# Epoch 29/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0337 - mae: 0.0615 - val_loss: 0.0135 - val_mae: 0.0870
# Epoch 30/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0320 - mae: 0.0582 - val_loss: 0.0073 - val_mae: 0.0586
# Epoch 31/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0328 - mae: 0.0577 - val_loss: 0.0097 - val_mae: 0.0708
# Epoch 32/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0317 - mae: 0.0553 - val_loss: 0.0076 - val_mae: 0.0587
# Epoch 33/50
# 89/89 [==============================] - 1s 10ms/step - loss: 0.0307 - mae: 0.0549 - val_loss: 0.0042 - val_mae: 0.0497
# Epoch 34/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0333 - mae: 0.0561 - val_loss: 0.0044 - val_mae: 0.0486
# Epoch 35/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0324 - mae: 0.0557 - val_loss: 0.0061 - val_mae: 0.0580
# Epoch 36/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0323 - mae: 0.0524 - val_loss: 0.0086 - val_mae: 0.0759
# Epoch 37/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0311 - mae: 0.0510 - val_loss: 0.0061 - val_mae: 0.0580
# Epoch 38/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0298 - mae: 0.0470 - val_loss: 0.0033 - val_mae: 0.0407
# Epoch 39/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0306 - mae: 0.0505 - val_loss: 0.0035 - val_mae: 0.0495
# Epoch 40/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0309 - mae: 0.0472 - val_loss: 0.0054 - val_mae: 0.0583
# Epoch 41/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0291 - mae: 0.0472 - val_loss: 0.0025 - val_mae: 0.0371
# Epoch 42/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0303 - mae: 0.0474 - val_loss: 0.0026 - val_mae: 0.0418
# Epoch 43/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0276 - mae: 0.0452 - val_loss: 0.0024 - val_mae: 0.0388
# Epoch 44/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0297 - mae: 0.0430 - val_loss: 0.0024 - val_mae: 0.0394
# Epoch 45/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0280 - mae: 0.0423 - val_loss: 0.0020 - val_mae: 0.0338
# Epoch 46/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0287 - mae: 0.0462 - val_loss: 0.0028 - val_mae: 0.0380
# Epoch 47/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0282 - mae: 0.0449 - val_loss: 0.0017 - val_mae: 0.0304
# Epoch 48/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0270 - mae: 0.0476 - val_loss: 0.0016 - val_mae: 0.0278
# Epoch 49/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0277 - mae: 0.0409 - val_loss: 0.0032 - val_mae: 0.0464
# Epoch 50/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0260 - mae: 0.0426 - val_loss: 0.0018 - val_mae: 0.0317

# %%
RNN_df = pd.DataFrame(history_1.history)
RNN_df.tail()
# Out:
#         loss       mae  val_loss   val_mae
# 45  0.028713  0.046207  0.002791  0.037950
# 46  0.028225  0.044919  0.001715  0.030448
# 47  0.027041  0.047562  0.001630  0.027821
# 48  0.027682  0.040873  0.003220  0.046445
# 49  0.025967  0.042630  0.001794  0.031657

# %%
print('')
plt.figure(figsize=(9,5))
plt.plot(RNN_df['loss'], label ='Training loss (MSE)', color = 'blue')
plt.plot(RNN_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
plt.xlabel('Mini-batch', fontsize=13)
plt.ylabel('Loss', fontsize=13)
plt.legend(fontsize=13)
plt.savefig('images/RNN_error1.eps', format='eps', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
np.random.seed(123)
history_2=LSTM_Model.fit(xtrain,ytrain, validation_data=(xvalid,yvalid), epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 89/89 [==============================] - 7s 20ms/step - loss: 6.1603 - mae: 2.0608 - val_loss: 0.5650 - val_mae: 0.6548
# Epoch 2/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0757 - mae: 0.1439 - val_loss: 0.0123 - val_mae: 0.0896
# Epoch 3/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0395 - mae: 0.0649 - val_loss: 0.0048 - val_mae: 0.0528
# Epoch 4/50
# 89/89 [==============================] - 1s 15ms/step - loss: 0.0366 - mae: 0.0586 - val_loss: 0.0080 - val_mae: 0.0724
# Epoch 5/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0353 - mae: 0.0593 - val_loss: 0.0044 - val_mae: 0.0498
# Epoch 6/50
# 89/89 [==============================] - 1s 14ms/step - loss: 0.0340 - mae: 0.0556 - val_loss: 0.0037 - val_mae: 0.0440
# Epoch 7/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0334 - mae: 0.0532 - val_loss: 0.0047 - val_mae: 0.0513
# Epoch 8/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0338 - mae: 0.0554 - val_loss: 0.0039 - val_mae: 0.0465
# Epoch 9/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0339 - mae: 0.0584 - val_loss: 0.0078 - val_mae: 0.0723
# Epoch 10/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0348 - mae: 0.0638 - val_loss: 0.0039 - val_mae: 0.0461
# Epoch 11/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0334 - mae: 0.0549 - val_loss: 0.0081 - val_mae: 0.0741
# Epoch 12/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0342 - mae: 0.0613 - val_loss: 0.0070 - val_mae: 0.0686
# Epoch 13/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0341 - mae: 0.0637 - val_loss: 0.0122 - val_mae: 0.0950
# Epoch 14/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0333 - mae: 0.0581 - val_loss: 0.0036 - val_mae: 0.0441
# Epoch 15/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0335 - mae: 0.0587 - val_loss: 0.0036 - val_mae: 0.0441
# Epoch 16/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0324 - mae: 0.0562 - val_loss: 0.0041 - val_mae: 0.0480
# Epoch 17/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0331 - mae: 0.0537 - val_loss: 0.0141 - val_mae: 0.1058
# Epoch 18/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0336 - mae: 0.0588 - val_loss: 0.0033 - val_mae: 0.0421
# Epoch 19/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0327 - mae: 0.0545 - val_loss: 0.0060 - val_mae: 0.0624
# Epoch 20/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0325 - mae: 0.0567 - val_loss: 0.0059 - val_mae: 0.0599
# Epoch 21/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0320 - mae: 0.0542 - val_loss: 0.0039 - val_mae: 0.0460
# Epoch 22/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0330 - mae: 0.0603 - val_loss: 0.0055 - val_mae: 0.0574
# Epoch 23/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0327 - mae: 0.0576 - val_loss: 0.0138 - val_mae: 0.1057
# Epoch 24/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0333 - mae: 0.0607 - val_loss: 0.0072 - val_mae: 0.0703
# Epoch 25/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0324 - mae: 0.0574 - val_loss: 0.0136 - val_mae: 0.1042
# Epoch 26/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0314 - mae: 0.0565 - val_loss: 0.0104 - val_mae: 0.0874
# Epoch 27/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0315 - mae: 0.0591 - val_loss: 0.0031 - val_mae: 0.0404
# Epoch 28/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0309 - mae: 0.0557 - val_loss: 0.0054 - val_mae: 0.0579
# Epoch 29/50
# 89/89 [==============================] - 1s 15ms/step - loss: 0.0306 - mae: 0.0550 - val_loss: 0.0049 - val_mae: 0.0535
# Epoch 30/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0299 - mae: 0.0523 - val_loss: 0.0041 - val_mae: 0.0494
# Epoch 31/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0307 - mae: 0.0601 - val_loss: 0.0042 - val_mae: 0.0496
# Epoch 32/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0296 - mae: 0.0538 - val_loss: 0.0123 - val_mae: 0.0993
# Epoch 33/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0296 - mae: 0.0593 - val_loss: 0.0047 - val_mae: 0.0527
# Epoch 34/50
# 89/89 [==============================] - 1s 14ms/step - loss: 0.0285 - mae: 0.0514 - val_loss: 0.0034 - val_mae: 0.0431
# Epoch 35/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0283 - mae: 0.0513 - val_loss: 0.0062 - val_mae: 0.0638
# Epoch 36/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0283 - mae: 0.0517 - val_loss: 0.0037 - val_mae: 0.0463
# Epoch 37/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0280 - mae: 0.0530 - val_loss: 0.0031 - val_mae: 0.0415
# Epoch 38/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0286 - mae: 0.0551 - val_loss: 0.0083 - val_mae: 0.0791
# Epoch 39/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0299 - mae: 0.0624 - val_loss: 0.0098 - val_mae: 0.0876
# Epoch 40/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0278 - mae: 0.0534 - val_loss: 0.0040 - val_mae: 0.0496
# Epoch 41/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0278 - mae: 0.0575 - val_loss: 0.0050 - val_mae: 0.0565
# Epoch 42/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0275 - mae: 0.0523 - val_loss: 0.0028 - val_mae: 0.0388
# Epoch 43/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0272 - mae: 0.0495 - val_loss: 0.0033 - val_mae: 0.0433
# Epoch 44/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0266 - mae: 0.0480 - val_loss: 0.0138 - val_mae: 0.1087
# Epoch 45/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0269 - mae: 0.0484 - val_loss: 0.0132 - val_mae: 0.1048
# Epoch 46/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0266 - mae: 0.0482 - val_loss: 0.0023 - val_mae: 0.0348
# Epoch 47/50
# 89/89 [==============================] - 1s 14ms/step - loss: 0.0274 - mae: 0.0546 - val_loss: 0.0028 - val_mae: 0.0394
# Epoch 48/50
# 89/89 [==============================] - 1s 14ms/step - loss: 0.0271 - mae: 0.0539 - val_loss: 0.0023 - val_mae: 0.0348
# Epoch 49/50
# 89/89 [==============================] - 1s 14ms/step - loss: 0.0280 - mae: 0.0603 - val_loss: 0.0022 - val_mae: 0.0336
# Epoch 50/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0259 - mae: 0.0451 - val_loss: 0.0031 - val_mae: 0.0433

# %%
LSTM_df = pd.DataFrame(history_2.history)
LSTM_df.tail()
# Out:
#         loss       mae  val_loss   val_mae
# 45  0.026635  0.048208  0.002346  0.034844
# 46  0.027377  0.054558  0.002820  0.039387
# 47  0.027121  0.053942  0.002300  0.034826
# 48  0.028050  0.060271  0.002197  0.033604
# 49  0.025908  0.045104  0.003108  0.043285

# %%
print('')
plt.figure(figsize=(9,5))
plt.plot(LSTM_df['loss'], label ='Training loss (MSE)', color = 'blue')
plt.plot(LSTM_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
plt.xlabel('Mini-batch', fontsize=13)
plt.ylabel('Loss', fontsize=13)
plt.legend(fontsize=13)
plt.savefig('images/LSTM_error1.eps', format='eps', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
np.random.seed(123)
history_3=GRU_Model.fit(xtrain,ytrain, validation_data=(xvalid,yvalid), epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 89/89 [==============================] - 6s 22ms/step - loss: 1.4989 - mae: 0.7924 - val_loss: 0.6878 - val_mae: 0.5139
# Epoch 2/50
# 89/89 [==============================] - 1s 10ms/step - loss: 0.1292 - mae: 0.1957 - val_loss: 0.0540 - val_mae: 0.1531
# Epoch 3/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0583 - mae: 0.0907 - val_loss: 0.0236 - val_mae: 0.1114
# Epoch 4/50
# 89/89 [==============================] - 1s 15ms/step - loss: 0.0537 - mae: 0.0749 - val_loss: 0.0154 - val_mae: 0.0834
# Epoch 5/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0518 - mae: 0.0703 - val_loss: 0.0119 - val_mae: 0.0717
# Epoch 6/50
# 89/89 [==============================] - 1s 10ms/step - loss: 0.0506 - mae: 0.0661 - val_loss: 0.0088 - val_mae: 0.0696
# Epoch 7/50
# 89/89 [==============================] - 1s 10ms/step - loss: 0.0493 - mae: 0.0616 - val_loss: 0.0071 - val_mae: 0.0583
# Epoch 8/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0485 - mae: 0.0608 - val_loss: 0.0064 - val_mae: 0.0585
# Epoch 9/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0479 - mae: 0.0610 - val_loss: 0.0064 - val_mae: 0.0556
# Epoch 10/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0476 - mae: 0.0639 - val_loss: 0.0053 - val_mae: 0.0524
# Epoch 11/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0468 - mae: 0.0630 - val_loss: 0.0046 - val_mae: 0.0495
# Epoch 12/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0466 - mae: 0.0630 - val_loss: 0.0043 - val_mae: 0.0474
# Epoch 13/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0456 - mae: 0.0601 - val_loss: 0.0081 - val_mae: 0.0740
# Epoch 14/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0454 - mae: 0.0621 - val_loss: 0.0105 - val_mae: 0.0867
# Epoch 15/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0456 - mae: 0.0627 - val_loss: 0.0099 - val_mae: 0.0834
# Epoch 16/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0451 - mae: 0.0618 - val_loss: 0.0046 - val_mae: 0.0499
# Epoch 17/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0448 - mae: 0.0606 - val_loss: 0.0084 - val_mae: 0.0768
# Epoch 18/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0443 - mae: 0.0603 - val_loss: 0.0072 - val_mae: 0.0686
# Epoch 19/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0447 - mae: 0.0643 - val_loss: 0.0040 - val_mae: 0.0453
# Epoch 20/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0439 - mae: 0.0619 - val_loss: 0.0040 - val_mae: 0.0461
# Epoch 21/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0435 - mae: 0.0579 - val_loss: 0.0060 - val_mae: 0.0596
# Epoch 22/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0440 - mae: 0.0638 - val_loss: 0.0045 - val_mae: 0.0488
# Epoch 23/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0431 - mae: 0.0601 - val_loss: 0.0095 - val_mae: 0.0804
# Epoch 24/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0436 - mae: 0.0646 - val_loss: 0.0048 - val_mae: 0.0511
# Epoch 25/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0433 - mae: 0.0647 - val_loss: 0.0049 - val_mae: 0.0521
# Epoch 26/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0429 - mae: 0.0629 - val_loss: 0.0065 - val_mae: 0.0623
# Epoch 27/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0429 - mae: 0.0629 - val_loss: 0.0178 - val_mae: 0.1199
# Epoch 28/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0440 - mae: 0.0704 - val_loss: 0.0062 - val_mae: 0.0607
# Epoch 29/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0424 - mae: 0.0638 - val_loss: 0.0091 - val_mae: 0.0801
# Epoch 30/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0430 - mae: 0.0681 - val_loss: 0.0116 - val_mae: 0.0911
# Epoch 31/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0418 - mae: 0.0617 - val_loss: 0.0209 - val_mae: 0.1284
# Epoch 32/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0441 - mae: 0.0748 - val_loss: 0.0041 - val_mae: 0.0467
# Epoch 33/50
# 89/89 [==============================] - 1s 13ms/step - loss: 0.0424 - mae: 0.0648 - val_loss: 0.0072 - val_mae: 0.0674
# Epoch 34/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0416 - mae: 0.0602 - val_loss: 0.0045 - val_mae: 0.0491
# Epoch 35/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0429 - mae: 0.0720 - val_loss: 0.0136 - val_mae: 0.1005
# Epoch 36/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0415 - mae: 0.0650 - val_loss: 0.0049 - val_mae: 0.0520
# Epoch 37/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0418 - mae: 0.0659 - val_loss: 0.0042 - val_mae: 0.0465
# Epoch 38/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0408 - mae: 0.0597 - val_loss: 0.0042 - val_mae: 0.0467
# Epoch 39/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0414 - mae: 0.0644 - val_loss: 0.0067 - val_mae: 0.0641
# Epoch 40/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0411 - mae: 0.0647 - val_loss: 0.0041 - val_mae: 0.0459
# Epoch 41/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0411 - mae: 0.0638 - val_loss: 0.0040 - val_mae: 0.0454
# Epoch 42/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0413 - mae: 0.0685 - val_loss: 0.0052 - val_mae: 0.0536
# Epoch 43/50
# 89/89 [==============================] - 1s 10ms/step - loss: 0.0403 - mae: 0.0637 - val_loss: 0.0049 - val_mae: 0.0521
# Epoch 44/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0406 - mae: 0.0635 - val_loss: 0.0039 - val_mae: 0.0447
# Epoch 45/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0409 - mae: 0.0678 - val_loss: 0.0101 - val_mae: 0.0866
# Epoch 46/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0403 - mae: 0.0655 - val_loss: 0.0059 - val_mae: 0.0612
# Epoch 47/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0396 - mae: 0.0618 - val_loss: 0.0061 - val_mae: 0.0621
# Epoch 48/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0397 - mae: 0.0606 - val_loss: 0.0049 - val_mae: 0.0535
# Epoch 49/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.0414 - mae: 0.0717 - val_loss: 0.0174 - val_mae: 0.1183
# Epoch 50/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.0405 - mae: 0.0726 - val_loss: 0.0065 - val_mae: 0.0634

# %%
GRU_df =pd.DataFrame(history_3.history)
GRU_df.tail()
# Out:
#         loss       mae  val_loss   val_mae
# 45  0.040316  0.065546  0.005938  0.061163
# 46  0.039622  0.061769  0.006059  0.062052
# 47  0.039662  0.060595  0.004889  0.053510
# 48  0.041424  0.071696  0.017440  0.118338
# 49  0.040520  0.072602  0.006539  0.063407

# %%
plt.figure(figsize=(9,5))
plt.plot(GRU_df['loss'], label ='Training loss (MSE)', color = 'blue')
plt.plot(GRU_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
plt.xlabel('Mini-batch', fontsize=13)
plt.ylabel('Loss', fontsize=13)
plt.legend(fontsize=13)
plt.savefig('images/GRU_error1.eps', format='eps', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
np.random.seed(123)
history_4 = MLP_Model.fit(xtrain, ytrain,
                          epochs=50,
                          validation_data=(xvalid, yvalid))
# Out:
# Epoch 1/50
# 89/89 [==============================] - 2s 6ms/step - loss: 2.5567 - mae: 0.9897 - val_loss: 0.0131 - val_mae: 0.0966
# Epoch 2/50
# 89/89 [==============================] - 0s 4ms/step - loss: 0.0381 - mae: 0.0692 - val_loss: 0.0088 - val_mae: 0.0802
# Epoch 3/50
# 89/89 [==============================] - 0s 4ms/step - loss: 0.0350 - mae: 0.0621 - val_loss: 0.0059 - val_mae: 0.0625
# Epoch 4/50
# 89/89 [==============================] - 0s 4ms/step - loss: 0.0317 - mae: 0.0543 - val_loss: 0.0046 - val_mae: 0.0559
# Epoch 5/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0292 - mae: 0.0479 - val_loss: 0.0055 - val_mae: 0.0602
# Epoch 6/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0278 - mae: 0.0452 - val_loss: 0.0048 - val_mae: 0.0556
# Epoch 7/50
# 89/89 [==============================] - 0s 6ms/step - loss: 0.0268 - mae: 0.0427 - val_loss: 0.0022 - val_mae: 0.0342
# Epoch 8/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0262 - mae: 0.0467 - val_loss: 0.0023 - val_mae: 0.0355
# Epoch 9/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0253 - mae: 0.0410 - val_loss: 0.0046 - val_mae: 0.0539
# Epoch 10/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0245 - mae: 0.0377 - val_loss: 0.0036 - val_mae: 0.0474
# Epoch 11/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0242 - mae: 0.0394 - val_loss: 0.0025 - val_mae: 0.0378
# Epoch 12/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0238 - mae: 0.0377 - val_loss: 0.0020 - val_mae: 0.0333
# Epoch 13/50
# 89/89 [==============================] - 0s 6ms/step - loss: 0.0235 - mae: 0.0382 - val_loss: 0.0019 - val_mae: 0.0323
# Epoch 14/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0230 - mae: 0.0366 - val_loss: 0.0022 - val_mae: 0.0350
# Epoch 15/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0235 - mae: 0.0403 - val_loss: 0.0015 - val_mae: 0.0260
# Epoch 16/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0236 - mae: 0.0431 - val_loss: 0.0034 - val_mae: 0.0458
# Epoch 17/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0230 - mae: 0.0399 - val_loss: 0.0017 - val_mae: 0.0292
# Epoch 18/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0231 - mae: 0.0395 - val_loss: 0.0020 - val_mae: 0.0327
# Epoch 19/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0226 - mae: 0.0367 - val_loss: 0.0025 - val_mae: 0.0394
# Epoch 20/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0231 - mae: 0.0417 - val_loss: 0.0068 - val_mae: 0.0718
# Epoch 21/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0225 - mae: 0.0373 - val_loss: 0.0014 - val_mae: 0.0255
# Epoch 22/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0224 - mae: 0.0369 - val_loss: 0.0021 - val_mae: 0.0351
# Epoch 23/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0226 - mae: 0.0384 - val_loss: 0.0014 - val_mae: 0.0244
# Epoch 24/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0224 - mae: 0.0385 - val_loss: 0.0046 - val_mae: 0.0540
# Epoch 25/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0226 - mae: 0.0384 - val_loss: 0.0016 - val_mae: 0.0274
# Epoch 26/50
# 89/89 [==============================] - 0s 4ms/step - loss: 0.0235 - mae: 0.0473 - val_loss: 0.0033 - val_mae: 0.0465
# Epoch 27/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0222 - mae: 0.0357 - val_loss: 0.0068 - val_mae: 0.0740
# Epoch 28/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0228 - mae: 0.0411 - val_loss: 0.0062 - val_mae: 0.0673
# Epoch 29/50
# 89/89 [==============================] - 0s 4ms/step - loss: 0.0226 - mae: 0.0406 - val_loss: 0.0021 - val_mae: 0.0346
# Epoch 30/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0223 - mae: 0.0373 - val_loss: 0.0016 - val_mae: 0.0287
# Epoch 31/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0223 - mae: 0.0357 - val_loss: 0.0015 - val_mae: 0.0274
# Epoch 32/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0221 - mae: 0.0354 - val_loss: 0.0014 - val_mae: 0.0249
# Epoch 33/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0227 - mae: 0.0415 - val_loss: 0.0050 - val_mae: 0.0594
# Epoch 34/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0225 - mae: 0.0387 - val_loss: 0.0028 - val_mae: 0.0425
# Epoch 35/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0221 - mae: 0.0357 - val_loss: 0.0041 - val_mae: 0.0544
# Epoch 36/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0224 - mae: 0.0370 - val_loss: 0.0015 - val_mae: 0.0266
# Epoch 37/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0223 - mae: 0.0393 - val_loss: 0.0025 - val_mae: 0.0394
# Epoch 38/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0234 - mae: 0.0463 - val_loss: 0.0020 - val_mae: 0.0328
# Epoch 39/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0225 - mae: 0.0389 - val_loss: 0.0020 - val_mae: 0.0336
# Epoch 40/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0225 - mae: 0.0419 - val_loss: 0.0037 - val_mae: 0.0502
# Epoch 41/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0224 - mae: 0.0357 - val_loss: 0.0022 - val_mae: 0.0366
# Epoch 42/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0222 - mae: 0.0358 - val_loss: 0.0066 - val_mae: 0.0742
# Epoch 43/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0229 - mae: 0.0431 - val_loss: 0.0060 - val_mae: 0.0691
# Epoch 44/50
# 89/89 [==============================] - 0s 6ms/step - loss: 0.0222 - mae: 0.0356 - val_loss: 0.0017 - val_mae: 0.0303
# Epoch 45/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0224 - mae: 0.0373 - val_loss: 0.0017 - val_mae: 0.0308
# Epoch 46/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0221 - mae: 0.0353 - val_loss: 0.0016 - val_mae: 0.0282
# Epoch 47/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0217 - mae: 0.0332 - val_loss: 0.0031 - val_mae: 0.0465
# Epoch 48/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0221 - mae: 0.0369 - val_loss: 0.0017 - val_mae: 0.0299
# Epoch 49/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0224 - mae: 0.0369 - val_loss: 0.0026 - val_mae: 0.0400
# Epoch 50/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0221 - mae: 0.0383 - val_loss: 0.0022 - val_mae: 0.0354

# %%
MLP_df =pd.DataFrame(history_4.history)
MLP_df.tail()
# Out:
#         loss       mae  val_loss   val_mae
# 45  0.022082  0.035339  0.001595  0.028240
# 46  0.021720  0.033211  0.003122  0.046472
# 47  0.022134  0.036886  0.001714  0.029907
# 48  0.022358  0.036899  0.002629  0.039993
# 49  0.022082  0.038286  0.002247  0.035446

# %%
plt.figure(figsize=(9,5))
plt.plot(MLP_df['loss'], label ='Training loss (MSE)', color = 'blue')
plt.plot(MLP_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
plt.xlabel('Mini-batch', fontsize=13)
plt.ylabel('Loss', fontsize=13)
plt.legend(fontsize=13)
plt.savefig('images/MLP_Model.eps', format='eps', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
np.random.seed(1)
history_5 = conv1D_Model.fit(xtrain,ytrain,batch_size=300,epochs=50,validation_data=(xvalid,yvalid), verbose = 1)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 2s 57ms/step - loss: 9.1405 - mae: 2.7407 - val_loss: 22.6357 - val_mae: 4.6005
# Epoch 2/50
# 10/10 [==============================] - 0s 11ms/step - loss: 7.2869 - mae: 2.3916 - val_loss: 17.2035 - val_mae: 3.8825
# Epoch 3/50
# 10/10 [==============================] - 0s 10ms/step - loss: 5.0080 - mae: 1.8973 - val_loss: 9.8501 - val_mae: 2.8063
# Epoch 4/50
# 10/10 [==============================] - 0s 13ms/step - loss: 2.4698 - mae: 1.2470 - val_loss: 4.0197 - val_mae: 1.6580
# Epoch 5/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.8627 - mae: 0.6726 - val_loss: 1.0470 - val_mae: 0.8053
# Epoch 6/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2118 - mae: 0.3290 - val_loss: 0.1531 - val_mae: 0.3416
# Epoch 7/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0784 - mae: 0.1832 - val_loss: 0.0271 - val_mae: 0.1249
# Epoch 8/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0657 - mae: 0.1620 - val_loss: 0.0123 - val_mae: 0.0927
# Epoch 9/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0541 - mae: 0.1248 - val_loss: 0.0146 - val_mae: 0.1009
# Epoch 10/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0473 - mae: 0.0959 - val_loss: 0.0227 - val_mae: 0.1346
# Epoch 11/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0456 - mae: 0.0870 - val_loss: 0.0234 - val_mae: 0.1370
# Epoch 12/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0447 - mae: 0.0856 - val_loss: 0.0185 - val_mae: 0.1199
# Epoch 13/50
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0439 - mae: 0.0859 - val_loss: 0.0151 - val_mae: 0.1082
# Epoch 14/50
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0433 - mae: 0.0859 - val_loss: 0.0138 - val_mae: 0.1038
# Epoch 15/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0428 - mae: 0.0856 - val_loss: 0.0136 - val_mae: 0.1035
# Epoch 16/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0423 - mae: 0.0841 - val_loss: 0.0150 - val_mae: 0.1092
# Epoch 17/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0418 - mae: 0.0829 - val_loss: 0.0149 - val_mae: 0.1094
# Epoch 18/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0412 - mae: 0.0812 - val_loss: 0.0133 - val_mae: 0.1010
# Epoch 19/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0407 - mae: 0.0801 - val_loss: 0.0138 - val_mae: 0.1044
# Epoch 20/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0401 - mae: 0.0787 - val_loss: 0.0127 - val_mae: 0.0981
# Epoch 21/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0395 - mae: 0.0766 - val_loss: 0.0125 - val_mae: 0.0972
# Epoch 22/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0389 - mae: 0.0752 - val_loss: 0.0118 - val_mae: 0.0942
# Epoch 23/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0382 - mae: 0.0728 - val_loss: 0.0108 - val_mae: 0.0889
# Epoch 24/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0375 - mae: 0.0705 - val_loss: 0.0105 - val_mae: 0.0879
# Epoch 25/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0368 - mae: 0.0677 - val_loss: 0.0095 - val_mae: 0.0823
# Epoch 26/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0361 - mae: 0.0646 - val_loss: 0.0083 - val_mae: 0.0751
# Epoch 27/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0354 - mae: 0.0620 - val_loss: 0.0086 - val_mae: 0.0783
# Epoch 28/50
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0347 - mae: 0.0590 - val_loss: 0.0064 - val_mae: 0.0644
# Epoch 29/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0340 - mae: 0.0561 - val_loss: 0.0063 - val_mae: 0.0646
# Epoch 30/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0335 - mae: 0.0534 - val_loss: 0.0051 - val_mae: 0.0564
# Epoch 31/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0329 - mae: 0.0507 - val_loss: 0.0048 - val_mae: 0.0546
# Epoch 32/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0324 - mae: 0.0483 - val_loss: 0.0039 - val_mae: 0.0477
# Epoch 33/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0320 - mae: 0.0467 - val_loss: 0.0036 - val_mae: 0.0458
# Epoch 34/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0316 - mae: 0.0450 - val_loss: 0.0030 - val_mae: 0.0404
# Epoch 35/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0312 - mae: 0.0437 - val_loss: 0.0043 - val_mae: 0.0515
# Epoch 36/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0311 - mae: 0.0453 - val_loss: 0.0027 - val_mae: 0.0377
# Epoch 37/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0307 - mae: 0.0421 - val_loss: 0.0034 - val_mae: 0.0444
# Epoch 38/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0304 - mae: 0.0412 - val_loss: 0.0025 - val_mae: 0.0361
# Epoch 39/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0302 - mae: 0.0406 - val_loss: 0.0026 - val_mae: 0.0367
# Epoch 40/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0300 - mae: 0.0398 - val_loss: 0.0025 - val_mae: 0.0353
# Epoch 41/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0298 - mae: 0.0404 - val_loss: 0.0024 - val_mae: 0.0345
# Epoch 42/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0296 - mae: 0.0389 - val_loss: 0.0024 - val_mae: 0.0344
# Epoch 43/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0294 - mae: 0.0398 - val_loss: 0.0024 - val_mae: 0.0343
# Epoch 44/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0293 - mae: 0.0384 - val_loss: 0.0024 - val_mae: 0.0351
# Epoch 45/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0292 - mae: 0.0402 - val_loss: 0.0024 - val_mae: 0.0343
# Epoch 46/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0290 - mae: 0.0394 - val_loss: 0.0023 - val_mae: 0.0335
# Epoch 47/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0289 - mae: 0.0380 - val_loss: 0.0023 - val_mae: 0.0335
# Epoch 48/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0288 - mae: 0.0385 - val_loss: 0.0023 - val_mae: 0.0334
# Epoch 49/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0287 - mae: 0.0391 - val_loss: 0.0022 - val_mae: 0.0332
# Epoch 50/50
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0286 - mae: 0.0379 - val_loss: 0.0022 - val_mae: 0.0331

# %%
conv1D_df = pd.DataFrame(history_5.history)
conv1D_df.tail()
# Out:
#         loss       mae  val_loss   val_mae
# 45  0.029047  0.039355  0.002277  0.033485
# 46  0.028923  0.038049  0.002272  0.033469
# 47  0.028830  0.038512  0.002271  0.033430
# 48  0.028661  0.039129  0.002241  0.033152
# 49  0.028635  0.037901  0.002237  0.033124

# %%
print('')
plt.figure(figsize=(9,5))
plt.plot(conv1D_df['loss'], label ='Training loss (MSE)', color = 'blue')
plt.plot(conv1D_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
plt.xlabel('Mini-batch', fontsize=13)
plt.ylabel('Loss', fontsize=13)
plt.legend(fontsize=13)
plt.savefig('images/conv1D_Model.eps', format='eps', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Predictions
# Now we will use our model to make predictions.

# %%
real_pred1 = RNN.predict(xtest)
real_pred2 = LSTM_Model.predict(xtest)
real_pred3 = GRU_Model.predict(xtest)
real_pred4 = MLP_Model.predict(xtest)
real_pred5 = conv1D_Model.predict(xtest)
# Out:
# 30/30 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 1s 5ms/step
# 30/30 [==============================] - 1s 5ms/step
# 30/30 [==============================] - 0s 3ms/step
# 30/30 [==============================] - 0s 3ms/step

# %%
real_pred1.shape,real_pred2.shape,real_pred3.shape,real_pred4.shape,real_pred5.shape
# Out:
# ((949, 5, 1), (949, 5), (949, 5, 1), (949, 5), (949, 5, 1))

# %%
# Combined Models
Pred_Data = pd.DataFrame({
    'RNN': real_pred1[:,0].flatten(),
    'LSTM': real_pred2[:,0].flatten(),
    'GRU': real_pred3[:,0].flatten(),
    'MLP': real_pred4[:,0].flatten(),  
    'conv1D': real_pred5[:,0].flatten(),  
    'Actual Rate': xtest[:,0].flatten()
})

Pred_Data.head()
# Out:
#         RNN      LSTM       GRU       MLP    conv1D  Actual Rate
# 0  5.948361  5.874539  5.994513  5.904864  5.905824       5.9385
# 1  5.948372  5.870703  5.951940  5.909400  5.909331       5.8972
# 2  5.908739  5.859576  5.973697  5.880883  5.900522       5.9183
# 3  5.901913  5.853568  5.973697  5.861912  5.892575       5.9183
# 4  5.901998  5.847326  5.973697  5.855451  5.887012       5.9183

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(19,10))

axs[0,0].plot(RNN_df['loss'], label ='Training ', color = 'blue')
axs[0,0].plot(RNN_df['val_loss'], label='Validation ', color = 'orange')
axs[0,0].set_title('RNN (Loss / Mean Square Error)')

axs[0,1].plot(LSTM_df['loss'], label ='Training loss (MSE)', color = 'blue')
axs[0,1].plot(LSTM_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
axs[0,1].set_title('LSTM (Loss / Mean Square Error)')

axs[0,2].plot(GRU_df['loss'], label ='Training ', color = 'blue')
axs[0,2].plot(GRU_df['val_loss'], label='Validation ', color = 'orange')
axs[0,2].set_title('GRU (Loss / Mean Square Error)')

axs[1,0].plot(MLP_df['loss'], label ='Training ', color = 'blue')
axs[1,0].plot(MLP_df['val_loss'], label='Validation ', color = 'orange')
axs[1,0].set_title('MLP (Loss / Mean Square Error)')

axs[1,1].plot(conv1D_df['loss'], label ='Training', color = 'blue')
axs[1,1].plot(conv1D_df['val_loss'], label='Validation ', color = 'orange')
axs[1,1].set_title('conv1D (Loss / Mean Square Error)')

axs[1,2].set_title('Loss Function')
# Add a blank subplot to fill the last space in the grid
axs[1,2].axis('off')
#Add legend to all plots
axs[0,0].legend(loc='upper left')
axs[0,1].legend(loc='upper left')
axs[0,2].legend(loc='upper left')
axs[1,0].legend(loc='upper left')
axs[1,1].legend(loc='upper left')
# Add a shared x-axis label to the bottom row of subplots
for ax in axs[1,:]:
    ax.set_xlabel('Epochs', fontsize=13)

# Add a shared y-axis label to the left column of subplots
for ax in axs[:,0]:
    ax.set_ylabel('Loss', fontsize=13)
    


    
plt.tight_layout()
plt.savefig('images/Combined3.eps', format='eps', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Combined Plots

# %%
plt.figure(figsize=(19,8))
plt.plot(Pred_Data['RNN'], color = 'red', label = 'RNN')
plt.plot(Pred_Data['LSTM'], color = 'green', label = 'LSTM')
plt.plot(Pred_Data['GRU'], color = 'orange', label = 'GRU')
plt.plot(Pred_Data['MLP'], color = 'maroon', label = 'MLP')
plt.plot(Pred_Data['conv1D'], color = 'black', label = 'conv1D')
plt.plot(xtest[:,0,0].flatten(), color = 'blue', label = 'Actual Rate')
plt.xlabel('Time (days)', fontsize=13)
plt.ylabel('Loss', fontsize=13)
plt.legend(fontsize=13)
plt.savefig('images/Combined1.eps', format='eps', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15,8))

axs[0,0].plot(Pred_Data['RNN'], color='red', label='RNN')
axs[0,0].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[0,0].set_title('RNN vs Actual Rate')

axs[0,1].plot(Pred_Data['LSTM'], color='green', label='LSTM')
axs[0,1].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[0,1].set_title('LSTM vs Actual Rate')

axs[0,2].plot(Pred_Data['GRU'], color='orange', label='GRU')
axs[0,2].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[0,2].set_title('GRU vs Actual Rate')

axs[1,0].plot(Pred_Data['MLP'], color='maroon', label='MLP')
axs[1,0].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[1,0].set_title('MLP vs Actual Rate')

axs[1,1].plot(Pred_Data['conv1D'], color='navy', label='conv1D')
axs[1,1].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[1,1].set_title('conv1D vs Actual Rate')

axs[1,2].plot(Pred_Data['RNN'], color = 'red', label = 'RNN')
axs[1,2].plot(Pred_Data['LSTM'], color = 'green', label = 'LSTM')
axs[1,2].plot(Pred_Data['GRU'], color = 'orange', label = 'GRU')
axs[1,2].plot(Pred_Data['MLP'], color = 'maroon', label = 'MLP')
axs[1,2].plot(Pred_Data['conv1D'], color = 'black', label = 'conv1D')
axs[1,2].plot(xtest[:,0,0].flatten(), color = 'blue', label = 'Actual Rate')

axs[1,2].set_title('Combined Plots')
# Add a blank subplot to fill the last space in the grid
axs[1,2].axis('off')

axs[0,0].legend(loc='upper left')
axs[0,1].legend(loc='upper left')
axs[0,2].legend(loc='upper left')
axs[1,0].legend(loc='upper left')
axs[1,1].legend(loc='upper left')
axs[1,2].legend(loc='upper left')
# Add a shared x-axis label to the bottom row of subplots
for ax in axs[1,:]:
    ax.set_xlabel('Time (days)', fontsize=13)

# Add a shared y-axis label to the left column of subplots
for ax in axs[:,0]:
    ax.set_ylabel('GHS/USD Rates', fontsize=13)
    

plt.tight_layout()
plt.savefig('images/Combined2.png', format='png', dpi=1000)
plt.show()

# %%
# plt.figure(figsize=(19,8))
# plt.plot(Pred_Data['RNN'], color='red', label='RNN')
# plt.plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
# plt.xlabel('Time (days)', fontsize=13)
# plt.ylabel('Exchange Rate', fontsize=13)
# plt.title('RNN vs Actual Rate', fontsize=13)
# plt.legend(fontsize=13,loc='upper left', ncol=2)
# plt.show()

# %%
# Assuming xtest is the test data and has shape (num_samples, num_timesteps, num_features)
rnn_pred = RNN.predict(xtest)
lstm_pred = LSTM_Model.predict(xtest)
gru_pred = GRU_Model.predict(xtest)
mlp_pred = MLP_Model.predict(xtest)
conv1d_pred = conv1D_Model.predict(xtest)
# Out:
# 30/30 [==============================] - 0s 3ms/step
# 30/30 [==============================] - 0s 5ms/step
# 30/30 [==============================] - 0s 5ms/step
# 30/30 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 3ms/step

# %%
# Combined Models
Pred_Data = pd.DataFrame({
    'RNN': rnn_pred[:,0].flatten(),
    'LSTM': lstm_pred[:,0].flatten(),
    'GRU': gru_pred[:,0].flatten(),
    'MLP': mlp_pred[:,0].flatten(),  # fixed typo here
    'conv1D': conv1d_pred[:,0].flatten(),  # fixed typo here
    'Actual Rate': xtest[:,0].flatten()
})

Pred_Data.head()
# Out:
#         RNN      LSTM       GRU       MLP    conv1D  Actual Rate
# 0  5.948361  5.874539  5.994513  5.904864  5.905824       5.9385
# 1  5.948372  5.870703  5.951940  5.909400  5.909331       5.8972
# 2  5.908739  5.859576  5.973697  5.880883  5.900522       5.9183
# 3  5.901913  5.853568  5.973697  5.861912  5.892575       5.9183
# 4  5.901998  5.847326  5.973697  5.855451  5.887012       5.9183

# %%
actuals = ytest.reshape(-1, 1)
actuals.shape,Pred_Data.shape
# Out:
# ((949, 1), (949, 6))

# %%
# print('')
# plt.figure(figsize=(10,5))
# plt.plot(actuals, label="Actual Rate", color = 'blue')
# plt.plot(Pred_Data['RNN'], label="RNN", color = 'red')
# plt.xlabel('Time (days)', fontsize=13)
# plt.ylabel('Rate', fontsize=13)
# plt.legend(fontsize=13)
# plt.show()

# %%
print('The the mean absolute error committed by the standard RNN model is: ', mean_absolute_error(actuals,Pred_Data['RNN']))
# Out:
# The the mean absolute error committed by the standard RNN model is:  0.03953548379542329

# %%
# Evaluate RNN predictions
rnn_mae = mean_absolute_error(ytest, Pred_Data['RNN'])
rnn_mse = mean_squared_error(ytest, Pred_Data['RNN'])
rnn_rmse = np.sqrt(rnn_mse)
rnn_r2 = r2_score(ytest, Pred_Data['RNN'])

# Evaluate LSTM predictions
lstm_mae = mean_absolute_error(ytest, Pred_Data['LSTM'])
lstm_mse = mean_squared_error(ytest, Pred_Data['LSTM'])
lstm_rmse = np.sqrt(lstm_mse)
lstm_r2 = r2_score(ytest, Pred_Data['LSTM'])

# Evaluate GRU predictions
gru_mae = mean_absolute_error(ytest, Pred_Data['GRU'])
gru_mse = mean_squared_error(ytest, Pred_Data['GRU'])
gru_rmse = np.sqrt(gru_mse)
gru_r2 = r2_score(ytest, Pred_Data['GRU'])

# Evaluate MLP predictions
mlp_mae = mean_absolute_error(ytest, Pred_Data['MLP'])
mlp_mse = mean_squared_error(ytest, Pred_Data['MLP'])
mlp_rmse = np.sqrt(mlp_mse)
mlp_r2 = r2_score(ytest, Pred_Data['MLP'])

# Evaluate Conv1D predictions
conv1d_mae = mean_absolute_error(ytest, Pred_Data['conv1D'])
conv1d_mse = mean_squared_error(ytest, Pred_Data['conv1D'])
conv1d_rmse = np.sqrt(conv1d_mse)
conv1d_r2 = r2_score(ytest, Pred_Data['conv1D'])

# %%
print("RNN Evaluation Metrics:")
print(f"MAE: {rnn_mae:.4f}, MSE: {rnn_mse:.4f}, RMSE: {rnn_rmse:.4f}, R2: {rnn_r2:.4f}\n")

print("LSTM Evaluation Metrics:")
print(f"MAE: {lstm_mae:.4f}, MSE: {lstm_mse:.4f}, RMSE: {lstm_rmse:.4f}, R2: {lstm_r2:.4f}\n")

print("GRU Evaluation Metrics:")
print(f"MAE: {gru_mae:.4f}, MSE: {gru_mse:.4f}, RMSE: {gru_rmse:.4f}, R2: {gru_r2:.4f}\n")

print("MLP Evaluation Metrics:")
print(f"MAE: {mlp_mae:.4f}, MSE: {mlp_mse:.4f}, RMSE: {mlp_rmse:.4f}, R2: {mlp_r2:.4f}\n")

print("Conv1D Evaluation Metrics:")
print(f"MAE: {conv1d_mae:.4f}, MSE: {conv1d_mse:.4f}, RMSE: {conv1d_rmse:.4f}, R2: {conv1d_r2:.4f}\n")
# Out:
# RNN Evaluation Metrics:
# MAE: 0.0395, MSE: 0.0023, RMSE: 0.0479, R2: 0.9904
#
# LSTM Evaluation Metrics:
# MAE: 0.0806, MSE: 0.0086, RMSE: 0.0930, R2: 0.9638
#
# GRU Evaluation Metrics:
# MAE: 0.0787, MSE: 0.0105, RMSE: 0.1022, R2: 0.9562
#
# MLP Evaluation Metrics:
# MAE: 0.0294, MSE: 0.0017, RMSE: 0.0415, R2: 0.9928
#
# Conv1D Evaluation Metrics:
# MAE: 0.0422, MSE: 0.0035, RMSE: 0.0588, R2: 0.9855

# %%
# Create a DataFrame with evaluation metrics
Results = pd.DataFrame({'MAE': [rnn_mae, lstm_mae, gru_mae, mlp_mae, conv1d_mae],
                        'MSE': [rnn_mse, lstm_mse, gru_mse, mlp_mse, conv1d_mse],
                        'RMSE': [rnn_rmse, lstm_rmse, gru_rmse, mlp_rmse, conv1d_rmse],
                        'R2': [rnn_r2, lstm_r2, gru_r2, mlp_r2, conv1d_r2]},
                       index=['RNN', 'LSTM', 'GRU', 'MLP', 'Conv1D'])
Results
# Out:
#              MAE       MSE      RMSE        R2
# RNN     0.039535  0.002296  0.047919  0.990384
# LSTM    0.080556  0.008647  0.092991  0.963789
# GRU     0.078681  0.010455  0.102249  0.956220
# MLP     0.029373  0.001719  0.041463  0.992801
# Conv1D  0.042233  0.003455  0.058780  0.985532
